# %% [markdown]
# # TRPO — EV2Gym V2G Profit Maximization Benchmark
#
# **Algorithm:** Trust Region Policy Optimization (Schulman et al. 2015)
# **Type:** on-policy · stochastic actor · KL-constrained policy updates
# **Library:** `sb3_contrib`
# **Scenario:** Workplace · 10 charging stations · 85 steps × 15 min
# **Reference:** Orfanoudakis et al. 2025 (arXiv:2404.01849), Table VII
# **Paper result (no HPO):** profit = 13.5 ± 8.5 € · sat = 57 ± 10 % · overload = 7 ± 13 kWh
#
# ## Protocol
#
# A two-phase Optuna HPO framework benchmarks TRPO on the V2G profit maximization
# task using EV2Gym Model 1 (workplace scenario, 10 charging stations, 85 steps × 15 min).
#
# 1. **Phase 1 — Algorithm HPO:** 30 TPE trials × 100k steps optimize the algorithm's
#    internal hyperparameters with the standard environment configuration.
# 2. **Phase 2 — Joint HPO (diagnostic):** 30 TPE trials × 100k steps jointly optimize
#    algorithm HPs and three environment parameters (`spawn_multiplier`,
#    `discharge_price_factor`, `transformer.max_power`). Phase 2 identifies
#    environment-induced performance ceilings and should not be interpreted as
#    achievable operational performance.
# 3. **Final training:** 1M steps with the Model-2 proxy reward (`PowerTrackingErrorMin`,
#    dense signal). 30 parallel environments via SubprocVecEnv.
# 4. **Evaluation:** Model-1 sparse reward (`profit_maximization`). 5 seeds × 20 episodes
#    = 100 episodes per phase. Seeds `[42, 123, 999, 7, 89]` (Henderson et al. 2018).
# 5. **Statistical testing:** Bootstrap 95% CIs + Wilcoxon signed-rank tests
#    (Agarwal et al. 2021).
# 6. **HPO budget sensitivity:** Best-so-far curves for 30/60/100 trials to validate
#    the 30-trial budget.
# 7. **Proxy reward ablation:** Direct comparison between the proxy-trained agent and
#    an agent trained on Model-1 reward, isolating the effect of reward substitution.
#
# ## Reward design
#
# Training uses the Model-2 dense proxy reward (§IV-C, EV2Gym paper): the dense signal
# accelerates credit assignment during learning. Evaluation always uses the Model-1 sparse
# reward so results are directly comparable to Table VII of the EV2Gym paper.
# VecNormalize observation statistics are frozen (`training=False`) before evaluation.
#
# ## How to run
#
# Set `MODE = 'PROD'` in Cell 1 for the full publishable run (~8–12 h on a GPU server
# with N_ENVS = 30). Use `MODE = 'TEST'` to verify correctness in minutes.

# %%
# ═══════════════════════════════════════════════════════════════════════════
#  MODE CONFIGURATION
#  Set MODE = 'TEST' to verify correctness end-to-end (minutes)
#  Set MODE = 'PROD' for the full publishable run (hours)
# ═══════════════════════════════════════════════════════════════════════════

MODE = 'PROD'   # <-- change to 'PROD' for production

if MODE == 'TEST':
    # ── Optuna ──────────────────────────────────────────────────────────────
    PHASE1_N_TRIALS  = 3          # PROD: 30
    PHASE2_N_TRIALS  = 3          # PROD: 30
    PHASE1_TIMESTEPS = 5_000      # PROD: 100_000
    PHASE2_TIMESTEPS = 5_000      # PROD: 100_000
    PHASE1_EVAL_EPS  = 2          # PROD: 8
    PHASE2_EVAL_EPS  = 2          # PROD: 8
    # ── Final training ──────────────────────────────────────────────────
    TOTAL_TIMESTEPS  = 10_000     # PROD: 1_000_000
    N_ENVS           = 4          # PROD: 30
    # ── Evaluation ──────────────────────────────────────────────────────────
    EVAL_SEEDS        = [42, 123]                  # PROD: [42, 123, 999, 7, 89]
    EPISODES_PER_SEED = 5                          # PROD: 20
    # ──  Bootstrap ──────────────────────────────────────────────────
    N_BOOTSTRAP      = 100        # PROD: 10_000
    # ──  Sensitivity ────────────────────────────────────────────────
    SENSITIVITY_TRIALS = [3, 5]   # PROD: [30, 60, 100]
    SENSITIVITY_STEPS  = 2_000    # PROD: 100_000
    # ──  Ablation reward ──────────────────────────────────────────────
    ABLATION_TIMESTEPS = 5_000    # PROD: 1_000_000
    ABLATION_N_ENVS    = 2        # PROD: 4
else:  # PROD
    # ── Optuna ──────────────────────────────────────────────────────────────
    PHASE1_N_TRIALS  = 30
    PHASE2_N_TRIALS  = 30
    PHASE1_TIMESTEPS = 100_000
    PHASE2_TIMESTEPS = 100_000
    PHASE1_EVAL_EPS  = 8
    PHASE2_EVAL_EPS  = 8
    # ── Final training ──────────────────────────────────────────────────
    TOTAL_TIMESTEPS  = 1_000_000
    N_ENVS           = 30
    # ── Evaluation ──────────────────────────────────────────────────────────
    EVAL_SEEDS        = [42, 123, 999, 7, 89]
    EPISODES_PER_SEED = 20
    # ──  Bootstrap ──────────────────────────────────────────────────
    N_BOOTSTRAP      = 10_000
    # ──  Sensitivity ────────────────────────────────────────────────
    SENSITIVITY_TRIALS = [30, 60, 100]
    SENSITIVITY_STEPS  = 100_000
    # ──  Ablation reward ──────────────────────────────────────────────
    ABLATION_TIMESTEPS = 1_000_000
    ABLATION_N_ENVS    = 4

EVAL_EPISODES = len(EVAL_SEEDS) * EPISODES_PER_SEED
print(f'Mode: {MODE}')
print(f'Optuna Phase 1/2: {PHASE1_N_TRIALS} trials × {PHASE1_TIMESTEPS:,} steps')
print(f'Training: {TOTAL_TIMESTEPS:,} steps | {N_ENVS} envs')
print(f'Evaluation: {len(EVAL_SEEDS)} seeds x {EPISODES_PER_SEED} eps = {EVAL_EPISODES} eps/phase')
print(f'Bootstrap: {N_BOOTSTRAP} iteraciones')
print(f'Sensitivity: {SENSITIVITY_TRIALS} trials x {SENSITIVITY_STEPS:,} steps')
print(f'Ablation: {ABLATION_TIMESTEPS:,} steps')
# Out:
# Mode: PROD
# Optuna Phase 1/2: 30 trials × 100,000 steps
# Training: 1,000,000 steps | 30 envs
# Evaluation: 5 seeds x 20 eps = 100 eps/phase
# Bootstrap: 10000 iteraciones
# Sensitivity: [30, 60, 100] trials x 100,000 steps
# Ablation: 1,000,000 steps

# %%
import copy, json, time, warnings, random
from pathlib import Path
from typing import Any, Dict, List

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import yaml
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
warnings.filterwarnings("ignore")

import torch
import sys
# START_METHOD: 'fork' on Linux VMs, 'spawn' on Windows/macOS
START_METHOD = "fork" if sys.platform.startswith("linux") else "spawn"

import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from sb3_contrib import TRPO

from ev2gym.rl_agent.reward import profit_maximization
from ev2gym.rl_agent.state  import V2G_profit_max

RESULTS_ROOT = Path("results_trpo_model1")
RESULTS_ROOT.mkdir(parents=True, exist_ok=True)
print("Results in:", RESULTS_ROOT)

# ── Reproducibility log ──────────────────────────────────────────────────────
REPRO_LOG = {
    "algorithm": "TRPO",
    "model": "Model1_V2G_Profit_Maximization",
    "training_reward": "Model-2 proxy (dense): r_t = -(P_set_{t-1} - P_tot_{t-1})^2",
    "evaluation_reward": "Model-1 (sparse): r_t = c_{t-1} - 100*eps_ov - 100*exp(-10*eps_usr)",
    "proxy_reward_note": "Agents are NOT trained on the satisfaction term. TRPO is on-policy: every rollout uses the proxy reward to compute advantages.",
    "trpo_specific_notes": {
        "algorithm_type": "On-policy trust-region constrained (Schulman et al. 2015)",
        "library": "sb3_contrib — NOT stable_baselines3",
        "no_replay_buffer": True,
        "kl_constraint": "Policy update constrained to KL(old||new) <= target_kl (sb3-contrib param name, via conjugate gradient)",
        "conjugate_gradient": "cg_max_steps iterations of CG to solve the natural gradient direction",
        "n_critic_updates": "Value function updated N times per rollout (separate from policy update)",
        "sub_sampling_factor": "Fraction of rollout buffer sampled for each update iteration",
        "no_clip_range": "TRPO uses target_kl (KL constraint), not clip_range (that is PPO-specific)",
        "line_search": "TRPO uses backtracking line search to ensure KL constraint is satisfied",
        "predecessor_of_ppo": "PPO approximates TRPO constraint with a simpler clip objective",
        "first_evaluation": "TRPO had no results in the original EV2Gym paper. This is the first evaluation on this benchmark."
    },
    "vecnorm_freeze": "VecNormalize stats frozen after training (training=False, norm_reward=False) before ALL evaluation episodes.",
    "eval_seeds": [42, 123, 999, 7, 89],
    "episodes_per_seed": 20,
    "total_eval_episodes": 100,  # 5 seeds x 20 eps
    "training_timesteps": 1_000_000,
    "n_parallel_envs": 30,
    "optuna_trials_per_phase": 30,
    "optuna_trial_timesteps": 100_000,
    "optuna_eval_episodes_per_trial": 8,
    "optuna_asymmetry_note": "F2 searches same 30 trials as F1 but across 3 additional YAML dims.",
    "mpc_horizon_note": "EV2Gym paper MPC uses horizon=25 steps (Table VII). Our reproduced variant could not match that config — treated as a distinct controller.",
    "paper_ref_note": "TRPO evaluated in EV2Gym Table VII WITHOUT HPO (default SB3). Our framework adds two-phase Optuna HPO — improvement over these values shows the contribution of systematic tuning.",
    "single_scenario_note": "All results are from the workplace scenario only.",
    "statistical_note": "High std relative to mean expected in Phase 2. Treat rankings as directional only without bootstrap CIs."
}
print("Reproducibility log initialized.")
# Out:
# Results in: results_trpo_model1
# Reproducibility log initialized.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# YAML Model 1 embebido
#  [not used in Model 1]: simulate_grid → Model 3 | power_setpoint → Model 2
#  charging_network_topology = string "None" → EV2Gym generates a random network topology
#
#  MPC HORIZON NOTE:
#  The EV2Gym paper (Table VII) uses the rolling-horizon MPC controller
#  (V2GProfitMaxOracle) with prediction+control horizon of 25 steps (§V-B).
#  Our reproduced MPC variant could not unambiguously match that config,
#  so it is treated as a distinct controller — not a faithful replication.
#  This explains the sign reversal in profit (+17.8 paper vs -7.6 ours).
# ─────────────────────────────────────────────────────────────────────────────

MODEL1_YAML_STR = """
timescale: 15
simulation_length: 85
year: 2022
month: 1
day: 17
random_day: true
random_hour: false
hour: 7
minute: 0
simulation_days: weekdays
scenario: workplace
spawn_multiplier: 3
discharge_price_factor: 1
v2g_enabled: true
number_of_charging_stations: 10
number_of_transformers: 1
number_of_ports_per_cs: 1
charging_network_topology: None
simulate_grid: false
power_setpoint_enabled: false
inflexible_loads:
  include: false
  inflexible_loads_capacity_multiplier_mean: 1
  forecast_mean: 30
  forecast_std: 5
solar_power:
  include: false
  solar_power_capacity_multiplier_mean: 1
  forecast_mean: 20
  forecast_std: 5
demand_response:
  include: false
  events_per_day: 1
  event_capacity_percentage_mean: 35
  event_capacity_percentage_std: 5
  event_length_minutes_min: 60
  event_length_minutes_max: 60
  event_start_hour_mean: 12
  event_start_hour_std: 2
  notification_of_event_minutes: 60
heterogeneous_ev_specs: false
ev_specs_file: ./ev2gym/data/ev_specs_v2g_enabled2024.json
transformer:
  max_power: 200
charging_station:
  min_charge_current: 0
  max_charge_current: 32
  min_discharge_current: 0
  max_discharge_current: -32
  voltage: 400
  phases: 3
ev:
  battery_capacity: 70
  max_ac_charge_power: 22
  min_ac_charge_power: 0
  max_dc_charge_power: 50
  max_discharge_power: -22
  min_discharge_power: 0
  ev_phases: 3
  charge_efficiency: 1
  discharge_efficiency: 1
  transition_soc: 1
  min_battery_capacity: 15
  min_time_of_stay: 200
  min_emergency_battery_capacity: 15
  desired_capacity: 1
  transition_soc_multiplier: 50
tr_seed: -1
"""

def save_cfg(cfg: dict, path) -> str:
    out = {}
    for k, v in cfg.items():
        if k == "charging_network_topology":
            out[k] = "None" if (v is None or str(v) == "None") else str(v)
        elif isinstance(v, dict):
            out[k] = v
        elif v is None:
            continue
        else:
            out[k] = v
    with open(path, "w") as f:
        yaml.dump(out, f, default_flow_style=False, allow_unicode=True)
    return str(path)

BASE_CFG = yaml.safe_load(MODEL1_YAML_STR)
MODEL1_YAML_PATH = RESULTS_ROOT / "model1_base.yaml"
save_cfg(BASE_CFG, MODEL1_YAML_PATH)
print("YAML saved to:", MODEL1_YAML_PATH)
for k in ["timescale","simulation_length","scenario","number_of_charging_stations",
          "v2g_enabled","simulate_grid","power_setpoint_enabled","spawn_multiplier"]:
    print(f"  {k}: {BASE_CFG.get(k)}")
# Out:
# YAML saved to: results_trpo_model1/model1_base.yaml
#   timescale: 15
#   simulation_length: 85
#   scenario: workplace
#   number_of_charging_stations: 10
#   v2g_enabled: True
#   simulate_grid: False
#   power_setpoint_enabled: False
#   spawn_multiplier: 3

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Utilities: seeding, vectorised environments, builder TRPO
#  SubprocVecEnv for training, DummyVecEnv for evaluation.
#  Metrics: EV2Gym exposes them in the info dict at the last step (done=True).
# ─────────────────────────────────────────────────────────────────────────────

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

def make_env_raw(config_file: str):
    return gym.make(
        "EV2Gym-v1",
        config_file     = config_file,
        reward_function = profit_maximization,
        state_function  = V2G_profit_max,
    )

def make_vec_train_env(config_file: str, seed: int = 42,
                       n_envs: int = N_ENVS) -> VecNormalize:
    def make_fn(rank):
        def _init():
            env = make_env_raw(config_file)
            env.reset(seed=seed + rank)
            return env
        return _init
    vec = SubprocVecEnv([make_fn(i) for i in range(n_envs)],
                        start_method=START_METHOD)
    return VecNormalize(vec, norm_obs=True, norm_reward=True, clip_obs=10.0)

def make_vec_train_env_optuna(config_file: str, seed: int = 42,
                               n_envs: int = 2) -> VecNormalize:
    def make_fn(rank):
        def _init():
            env = make_env_raw(config_file)
            env.reset(seed=seed + rank)
            return env
        return _init
    vec = SubprocVecEnv([make_fn(i) for i in range(n_envs)],
                        start_method=START_METHOD)
    return VecNormalize(vec, norm_obs=True, norm_reward=True, clip_obs=10.0)

def load_eval_env(config_file: str, vecnorm_path: str) -> VecNormalize:
    """
    Load VecNormalize for evaluation with stats frozen from training.

    REPRODUCIBILITY NOTE (C4 — VecNormalize freeze):
    - VecNormalize statistics were computed during training.
    - `training=False` stops updating those statistics during evaluation.
    - `norm_reward=False` returns raw reward so cumulative reward = Model-1 signal.
    - Both must be set BEFORE the first evaluation episode.
    - Asserts below enforce this — any accidental regression will raise immediately.

    Wrapper chain: VecNormalize → .venv → DummyVecEnv → .envs[0] → .unwrapped → EV2Gym
    """
    vec = DummyVecEnv([lambda cf=config_file: make_env_raw(cf)])
    vn  = VecNormalize.load(vecnorm_path, vec)
    vn.training    = False   # freeze: do NOT update running stats
    vn.norm_reward = False   # return raw reward for profit tracking
    assert not vn.training,    "VecNormalize must be frozen for evaluation"
    assert not vn.norm_reward, "norm_reward must be False for raw reward logging"
    return vn

def quick_eval(model, config_file: str, vecnorm_path: str, n_eps: int) -> float:
    eval_env = load_eval_env(config_file, vecnorm_path)
    rewards  = []
    for _ in range(n_eps):
        obs  = eval_env.reset()
        done = [False]
        ep_r = 0.0
        while not done[0]:
            action, _ = model.predict(obs, deterministic=True)
            obs, r, done, _ = eval_env.step(action)
            ep_r += float(r[0])
        rewards.append(ep_r)
    eval_env.close()
    return float(np.mean(rewards))

_env = make_env_raw(str(MODEL1_YAML_PATH))
_obs, _ = _env.reset()
print(f"Environment OK | obs: {{_obs.shape}} | action: {{_env.action_space.shape}}")
_env.close()
print(f"N_ENVS: {{N_ENVS}}")
# Out:
# Environment OK | obs: {_obs.shape} | action: {_env.action_space.shape}
# N_ENVS: {N_ENVS}

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Samplers Optuna para TRPO
#
#  TRPO-specific HPs (vs PPO):
#  + target_kl: max KL divergence allowed per update (sb3-contrib param name).
#    Central HP for TRPO — controls step size more directly than clip_range in PPO.
#  + cg_max_steps: conjugate gradient iterations for natural gradient direction.
#  + n_critic_updates: number of value function gradient steps per rollout.
#  + sub_sampling_factor: int, subsample rollout buffer by 1/N for each update.
#    sub_sampling_factor=1 means use the full buffer each update.
#  + line_search_shrinking_factor: backtracking factor (default 0.8, rarely tuned).
#
#  ABSENT from TRPO vs PPO: clip_range, ent_coef (as a tunable HP).
#  ABSENT from TRPO vs DDPG/TD3: action_noise, replay buffer, tau, batch_size.
#
#  Note: batch_size in TRPO is the minibatch size for the critic update only
#  (NOT a rollout buffer divisibility constraint like in PPO).
# ─────────────────────────────────────────────────────────────────────────────

def sample_arch(trial: optuna.Trial) -> dict:
    sizes = [64, 128, 256, 512]
    n = trial.suggest_int("n_layers", 2, 4)
    pi = [trial.suggest_categorical(f"pi_l{i}", sizes) for i in range(n)]
    vf = [trial.suggest_categorical(f"vf_l{i}", sizes) for i in range(n)]
    return {"pi": pi, "vf": vf}

def sample_algo_hparams(trial: optuna.Trial) -> dict:
    return {
        "learning_rate"     : trial.suggest_float("lr",         1e-5, 3e-3,  log=True),
        "gamma"             : trial.suggest_float("gamma",      0.90, 0.999),
        "n_steps"           : trial.suggest_categorical("n_steps", [512, 1024, 2048]),
        "batch_size"        : trial.suggest_categorical("bs",    [64, 128, 256]),
        "gae_lambda"        : trial.suggest_float("gae_lambda", 0.90, 0.999),
        "target_kl"         : trial.suggest_float("target_kl",  0.001, 0.05,  log=True),
        "cg_max_steps"      : trial.suggest_categorical("cg",   [10, 15, 20]),
        "n_critic_updates"  : trial.suggest_categorical("ncu",  [5, 10, 20]),
        "sub_sampling_factor": trial.suggest_categorical("ssf", [1, 2, 4]),
    }

def sample_yaml_params(trial: optuna.Trial, base_cfg: dict) -> dict:
    cfg = copy.deepcopy(base_cfg)
    cfg["spawn_multiplier"]         = trial.suggest_int("spawn_multiplier", 2, 6)
    cfg["discharge_price_factor"]   = trial.suggest_float("discharge_price_factor", 0.8, 1.5)
    cfg["transformer"]              = copy.deepcopy(base_cfg.get("transformer", {}))
    cfg["transformer"]["max_power"] = trial.suggest_int("transformer_max_power", 100, 300, step=50)
    return cfg

print("Samplers ready.")
# Out:
# Samplers ready.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Builder TRPO
#
#  TRPO (Schulman et al. 2015):
#  - On-policy: rollouts discarded after each update (no replay buffer).
#  - KL constraint replaces PPO's clip_range. Each update solves:
#      max_theta  L(theta)  subject to  KL(pi_old || pi_theta) <= target_kl
#    via conjugate gradient + backtracking line search.
#  - n_critic_updates: value function updated separately (MSE loss) N times.
#  - sub_sampling_factor: reduces memory/compute by using 1/N of the buffer.
#  - batch_size: minibatch for critic update (NOT constrained by n_steps like PPO).
#  - Proxy reward (Model-2 dense) used during training; Model-1 at evaluation.
# ─────────────────────────────────────────────────────────────────────────────

def build_model(hp: dict, arch: dict, env, seed: int = 42, n_envs: int = 1):
    """
    Build TRPO model (from sb3_contrib).

    Key notes:
    - batch_size here is the critic minibatch size, NOT subject to
      n_steps * n_envs divisibility like PPO. No adjustment needed.
    - target_kl is the primary step-size control HP (vs clip_range in PPO).
    - cg_max_steps: more iterations = more accurate natural gradient but slower.
    - sub_sampling_factor: 1=full buffer, 2=half buffer per update, etc.
    """
    policy_kwargs = dict(net_arch=dict(pi=arch["pi"], vf=arch["vf"]))

    return TRPO(
        "MlpPolicy", env,
        learning_rate      = hp.get("learning_rate",      3e-4),
        gamma              = hp.get("gamma",              0.99),
        n_steps            = hp.get("n_steps",            2048),
        batch_size         = hp.get("batch_size",         128),
        gae_lambda         = hp.get("gae_lambda",         0.95),
        target_kl          = hp.get("target_kl",          0.01),
        cg_max_steps       = hp.get("cg_max_steps",       15),
        n_critic_updates   = hp.get("n_critic_updates",   10),
        sub_sampling_factor= hp.get("sub_sampling_factor",1),
        policy_kwargs      = policy_kwargs,
        verbose            = 0,
        seed               = seed,
    )

print("Builder TRPO listo.")
# Out:
# Builder TRPO listo.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Optuna Phase 1: internal HPs TRPO (YAML fijo)
#  TEST    → 2 trials × 5_000 steps
#  PRODUCTION → 30 trials × 100_000 steps
# ─────────────────────────────────────────────────────────────────────────────

PHASE1_SEED      = 42

PHASE1_DIR = RESULTS_ROOT / "optuna_phase1"
PHASE1_DIR.mkdir(exist_ok=True)
set_seed(PHASE1_SEED)

def objective_phase1(trial: optuna.Trial) -> float:
    arch      = sample_arch(trial)
    hp        = sample_algo_hparams(trial)
    yaml_path = save_cfg(BASE_CFG, PHASE1_DIR / f"trial_{trial.number}.yaml")
    try:
        train_env = make_vec_train_env_optuna(yaml_path, seed=PHASE1_SEED, n_envs=2)
        model     = build_model(hp, arch, train_env, seed=PHASE1_SEED, n_envs=2)
        model.learn(total_timesteps=PHASE1_TIMESTEPS)
        vn_path = str(PHASE1_DIR / f"vn_{trial.number}.pkl")
        train_env.save(vn_path)
        train_env.close()
        return quick_eval(model, yaml_path, vn_path, PHASE1_EVAL_EPS)
    except Exception as e:
        print(f"  Trial {trial.number} fallido: {e}")
        return -1e9

study1 = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=PHASE1_SEED),
    study_name="trpo_phase1"
)
print(f"Phase 1: {PHASE1_N_TRIALS} trials × {PHASE1_TIMESTEPS:,} steps")
t0 = time.time()
study1.optimize(objective_phase1, n_trials=PHASE1_N_TRIALS, show_progress_bar=True)
print(f"Completed in {(time.time()-t0)/60:.1f} min")
print(f"Best trial #{study1.best_trial.number} | value={study1.best_value:.2f}")
study1.trials_dataframe().to_csv(RESULTS_ROOT / "optuna_phase1_trials.csv", index=False)

# ── Save convergence curve ────────────────────────────────────────────────────
best_so_far_p1 = []
best_val = -float("inf")
for trial in sorted(study1.trials, key=lambda t: t.number):
    if trial.value is not None and trial.value > best_val:
        best_val = trial.value
    best_so_far_p1.append({"trial": trial.number, "value": trial.value,
                            "best_so_far": best_val, "phase": "Phase1"})
pd.DataFrame(best_so_far_p1).to_csv(
    RESULTS_ROOT / "optuna_phase1_convergence.csv", index=False)
print(f"Convergence curve saved ({len(best_so_far_p1)} trials).")
# Out:
# Phase 1: 30 trials × 100,000 steps
#   0%|          | 0/30 [00:00<?, ?it/s]
# Completed in 337.7 min
# Best trial #22 | value=8.32
# Convergence curve saved (30 trials).

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Best HPs Phase 1
# ─────────────────────────────────────────────────────────────────────────────

p1 = study1.best_trial.params
best_arch_p1 = {
    "pi": [p1[f"pi_l{i}"] for i in range(p1["n_layers"])],
    "vf": [p1[f"vf_l{i}"] for i in range(p1["n_layers"])],
}
best_hp_p1 = {
    "learning_rate"      : p1["lr"],
    "gamma"              : p1["gamma"],
    "n_steps"            : p1["n_steps"],
    "batch_size"         : p1["bs"],
    "gae_lambda"         : p1["gae_lambda"],
    "target_kl"          : p1["target_kl"],
    "cg_max_steps"       : p1["cg"],
    "n_critic_updates"   : p1["ncu"],
    "sub_sampling_factor": p1["ssf"],
}

PHASE1_BEST_YAML = RESULTS_ROOT / "phase1_best_config.yaml"
save_cfg(BASE_CFG, PHASE1_BEST_YAML)
with open(RESULTS_ROOT / "phase1_best_params.json", "w") as f:
    json.dump({"best_value": study1.best_value,
               "arch": best_arch_p1, "hp": best_hp_p1}, f, indent=2)
print(f"Phase 1 best value: {study1.best_value:.2f}")
for k, v in best_hp_p1.items():
    print(f"  {k}: {v}")
# Out:
# Phase 1 best value: 8.32
#   learning_rate: 9.132888768997024e-05
#   gamma: 0.9880385875060959
#   n_steps: 2048
#   batch_size: 64
#   gae_lambda: 0.9511536378222661
#   target_kl: 0.0026873381074592256
#   cg_max_steps: 15
#   n_critic_updates: 5
#   sub_sampling_factor: 1

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Optuna Phase 2: internal HPs + YAML parameters
#  TEST    → 2 trials × 5_000 steps
#  PRODUCTION → 30 trials × 100_000 steps
# ─────────────────────────────────────────────────────────────────────────────

PHASE2_SEED      = 42

PHASE2_DIR = RESULTS_ROOT / "optuna_phase2"
PHASE2_DIR.mkdir(exist_ok=True)
set_seed(PHASE2_SEED)

def objective_phase2(trial: optuna.Trial) -> float:
    arch      = sample_arch(trial)
    hp        = sample_algo_hparams(trial)
    cfg_t     = sample_yaml_params(trial, BASE_CFG)
    yaml_path = save_cfg(cfg_t, PHASE2_DIR / f"trial_{trial.number}.yaml")
    try:
        train_env = make_vec_train_env_optuna(yaml_path, seed=PHASE2_SEED, n_envs=2)
        model     = build_model(hp, arch, train_env, seed=PHASE2_SEED, n_envs=2)
        model.learn(total_timesteps=PHASE2_TIMESTEPS)
        vn_path = str(PHASE2_DIR / f"vn_{trial.number}.pkl")
        train_env.save(vn_path)
        train_env.close()
        trial.set_user_attr("yaml_path", yaml_path)
        return quick_eval(model, yaml_path, vn_path, PHASE2_EVAL_EPS)
    except Exception as e:
        print(f"  Trial {trial.number} fallido: {e}")
        return -1e9

# # Phase 2 uses the same 30-trial budget as Phase 1 across 3 additional dimensions. Same budget across more dimensions = less
# coverage per HP. This asymmetry is a known limitation recorded in REPRO_LOG.
print("NOTE: Phase 2 covers the same trial budget as Phase 1 across 3 additional dimensions — lower per-HP coverage is a known trade-off.")
study2 = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=PHASE2_SEED),
    study_name="trpo_phase2"
)
print(f"Phase 2: {PHASE2_N_TRIALS} trials × {PHASE2_TIMESTEPS:,} steps")
t0 = time.time()
study2.optimize(objective_phase2, n_trials=PHASE2_N_TRIALS, show_progress_bar=True)
print(f"Completed in {(time.time()-t0)/60:.1f} min")
print(f"Best trial #{study2.best_trial.number} | value={study2.best_value:.2f}")
study2.trials_dataframe().to_csv(RESULTS_ROOT / "optuna_phase2_trials.csv", index=False)

# ── Save convergence curve ────────────────────────────────────────────────────
best_so_far_p2 = []
best_val = -float("inf")
for trial in sorted(study2.trials, key=lambda t: t.number):
    if trial.value is not None and trial.value > best_val:
        best_val = trial.value
    best_so_far_p2.append({"trial": trial.number, "value": trial.value,
                            "best_so_far": best_val, "phase": "Phase2"})
pd.DataFrame(best_so_far_p2).to_csv(
    RESULTS_ROOT / "optuna_phase2_convergence.csv", index=False)
print(f"Convergence curve saved ({len(best_so_far_p2)} trials).")
# Out:
# NOTE: Phase 2 covers the same trial budget as Phase 1 across 3 additional dimensions — lower per-HP coverage is a known trade-off.
# Phase 2: 30 trials × 100,000 steps
#   0%|          | 0/30 [00:00<?, ?it/s]
# Completed in 402.7 min
# Best trial #18 | value=28.34
# Convergence curve saved (30 trials).

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Best HPs Phase 2
# ─────────────────────────────────────────────────────────────────────────────

p2 = study2.best_trial.params
best_arch_p2 = {
    "pi": [p2[f"pi_l{i}"] for i in range(p2["n_layers"])],
    "vf": [p2[f"vf_l{i}"] for i in range(p2["n_layers"])],
}
best_hp_p2 = {
    "learning_rate"      : p2["lr"],
    "gamma"              : p2["gamma"],
    "n_steps"            : p2["n_steps"],
    "batch_size"         : p2["bs"],
    "gae_lambda"         : p2["gae_lambda"],
    "target_kl"          : p2["target_kl"],
    "cg_max_steps"       : p2["cg"],
    "n_critic_updates"   : p2["ncu"],
    "sub_sampling_factor": p2["ssf"],
}

best_cfg_p2 = sample_yaml_params(study2.best_trial, BASE_CFG)
PHASE2_BEST_YAML = RESULTS_ROOT / "phase2_best_config.yaml"
save_cfg(best_cfg_p2, PHASE2_BEST_YAML)
with open(RESULTS_ROOT / "phase2_best_params.json", "w") as f:
    json.dump({"best_value": study2.best_value,
               "arch": best_arch_p2, "hp": best_hp_p2,
               "yaml_params": {
                   "spawn_multiplier"      : p2.get("spawn_multiplier"),
                   "discharge_price_factor": p2.get("discharge_price_factor"),
                   "transformer_max_power" : p2.get("transformer_max_power"),
               }}, f, indent=2)
print(f"Phase 1: {study1.best_value:.2f} | Phase 2: {study2.best_value:.2f}")
print(f"Improvement: {study2.best_value - study1.best_value:+.2f}")
# Out:
# Phase 1: 8.32 | Phase 2: 28.34
# Improvement: +20.03

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Final training
#  Training reward : Model-2 proxy (dense) — on-policy rollouts for GAE advantage estimation
#  Evaluation reward: Model-1 (sparse) — V2G Profit Maximization
#  TEST    → 5_000 steps
#  PRODUCTION → 1_000_000 steps
# ─────────────────────────────────────────────────────────────────────────────

TRAIN_SEED      = 42

def train_final(hp, arch, yaml_path, label, seed=TRAIN_SEED):
    set_seed(seed)
    train_env = make_vec_train_env(str(yaml_path), seed=seed, n_envs=N_ENVS)
    model     = build_model(hp, arch, train_env, seed=seed, n_envs=N_ENVS)
    print(f"Training [" + label + f"] — {TOTAL_TIMESTEPS:,} steps | {N_ENVS} envs")
    t0 = time.time()
    model.learn(total_timesteps=TOTAL_TIMESTEPS, progress_bar=True)
    print(f"  Completed in {(time.time()-t0)/60:.1f} min")
    model_path   = str(RESULTS_ROOT / f"trpo_final_{label}")
    vecnorm_path = str(RESULTS_ROOT / f"vecnorm_{label}.pkl")
    model.save(model_path)
    train_env.save(vecnorm_path)
    train_env.close()
    # ── Save training metadata ────────────────────────────────────────────────
    meta = {
        "label": label,
        "algorithm": "TRPO",
        "training_reward": "Model-2 proxy (dense reward)",
        "evaluation_reward": "Model-1 (V2G Profit Maximization sparse reward)",
        "total_timesteps": TOTAL_TIMESTEPS,
        "n_envs": N_ENVS,
        "seed": seed,
        "model_path": model_path,
        "vecnorm_path": vecnorm_path,
        "vecnorm_frozen_for_eval": True,
    }
    with open(str(RESULTS_ROOT / f"training_meta_{label}.json"), "w") as fmeta:
        json.dump(meta, fmeta, indent=2)
    return model, vecnorm_path

model_p1, vn_path_p1 = train_final(best_hp_p1, best_arch_p1, PHASE1_BEST_YAML, "phase1")
model_p2, vn_path_p2 = train_final(best_hp_p2, best_arch_p2, PHASE2_BEST_YAML, "phase2")
print("Models trained.")
# Out:
# Training [phase1] — 1,000,000 steps | 30 envs
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   Completed in 29.2 min
# Training [phase2] — 1,000,000 steps | 30 envs
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   Completed in 60.6 min
# Models trained.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Rich evaluator: Table VII metrics
#  EV2Gym exposes metrics in the info dict at the last step (done=True).
# ─────────────────────────────────────────────────────────────────────────────

SCALAR_COLS = [
    "reward_total", "total_profit_cost", "user_satisfaction",
    "energy_charged_kwh", "energy_discharged_kwh",
    "transformer_overload_kwh", "battery_degradation",
    "battery_deg_calendar", "battery_deg_cyclic",
    "total_ev_served", "exec_time_s",
]

def run_episode_full(model, config_file: str, vecnorm_path: str,
                     ep_idx: int = 0, eval_seed: int = 42) -> dict:
    """
    Runs one evaluation episode and returns all Model-1 metrics.

    REPRODUCIBILITY NOTES:
    - eval_seed applied to env.reset() via formula: eval_seed * 1000 + ep_idx.
    - VecNormalize loaded fresh each call with training=False (freeze confirmed).
    - Metrics from info dict at final step (done=True) — EV2Gym populates all
      stats only at episode end; intermediate steps have action_mask only.
    - Training used Model-2 proxy reward; this evaluator reports Model-1 reward.
    """
    t_start    = time.time()
    eval_env   = load_eval_env(config_file, vecnorm_path)
    ep_seed    = eval_seed * 1000 + ep_idx   # unique per (seed, ep) pair
    # VecNormalize.reset() does not accept seed= in SB3.
    # We fix reproducibility by setting the global numpy/torch seed
    # to ep_seed immediately before reset. EV2Gym draws EV arrivals
    # and prices from numpy.random, so this fully determines the episode.
    set_seed(ep_seed)
    obs        = eval_env.reset()
    ts_reward  = []
    ts_action  = []
    cum_reward = 0.0
    done       = [False]
    final_info = {}
    while not done[0]:
        action, _ = model.predict(obs, deterministic=True)
        obs, r, done, info = eval_env.step(action)
        cum_reward += float(r[0])
        ts_reward.append(float(r[0]))
        ts_action.append(float(np.mean(action)))
        if done[0]:
            final_info = info[0] if isinstance(info, list) else info
    exec_time = time.time() - t_start
    eval_env.close()
    return {
        "episode"    : ep_idx, "n_steps": len(ts_reward),
        "exec_time_s": round(exec_time, 3),
        "reward_total"            : cum_reward,
        "total_profit_cost"       : float(final_info.get("total_profits",             0.0) or 0.0),
        "user_satisfaction"       : float(final_info.get("average_user_satisfaction", 0.0) or 0.0),
        "energy_charged_kwh"      : float(final_info.get("total_energy_charged",      0.0) or 0.0),
        "energy_discharged_kwh"   : float(final_info.get("total_energy_discharged",   0.0) or 0.0),
        "transformer_overload_kwh": float(final_info.get("total_transformer_overload",0.0) or 0.0),
        "battery_degradation"     : float(final_info.get("battery_degradation",       0.0) or 0.0),
        "battery_deg_calendar"    : float(final_info.get("battery_degradation_calendar", 0.0) or 0.0),
        "battery_deg_cyclic"      : float(final_info.get("battery_degradation_cycling",  0.0) or 0.0),
        "total_ev_served"         : float(final_info.get("total_ev_served",           0.0) or 0.0),
        "ts_reward": ts_reward, "ts_action": ts_action,
        "ts_cum_reward": list(np.cumsum(ts_reward)),
    }

print("Evaluator ready.")
# Out:
# Evaluator ready.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Evaluation
#  TEST    → 1 seed × 2 episodes
#  PRODUCTION → 5 seeds × 20 episodes = 100 per phase
# ─────────────────────────────────────────────────────────────────────────────

def evaluate_model(model, yaml_path, vecnorm_path: str, label: str) -> list:
    episodes   = []
    ep_counter = 0
    for seed in EVAL_SEEDS:
        set_seed(seed)  # global numpy/torch seed for this seed block
        for ep in range(EPISODES_PER_SEED):
            result = run_episode_full(
                model, str(yaml_path), vecnorm_path,
                ep_idx=ep_counter, eval_seed=seed  # per-episode env seed
            )
            result["seed"] = seed; result["phase"] = label
            episodes.append(result)
            ep_counter += 1
            print(f"  [{label}] Ep {ep_counter:2d}"
                  f" | reward={result['reward_total']:+.2f}"
                  f" | profit={result['total_profit_cost']:+.2f}€"
                  f" | sat={result['user_satisfaction']:.1%}"
                  f" | overload={result['transformer_overload_kwh']:.2f}kWh"
                  f" | Qlost={result['battery_degradation']:.5f}"
                  f" | EVs={int(result['total_ev_served'])}")
    return episodes

print("Evaluating Phase 1...")
eps_p1 = evaluate_model(model_p1, PHASE1_BEST_YAML, vn_path_p1, "Phase1_HP_only")
print("\nEvaluating Phase 2...")
eps_p2 = evaluate_model(model_p2, PHASE2_BEST_YAML, vn_path_p2, "Phase2_HP_YAML")
print(f"\nTotal: {len(eps_p1)+len(eps_p2)} episodes")
# Out:
# Evaluating Phase 1...
#   [Phase1_HP_only] Ep  1 | reward=+11.92 | profit=+19.87€ | sat=40.4% | overload=0.00kWh | Qlost=0.00020 | EVs=4
#   [Phase1_HP_only] Ep  2 | reward=+4.30 | profit=+9.48€ | sat=46.1% | overload=0.00kWh | Qlost=0.00013 | EVs=4
#   [Phase1_HP_only] Ep  3 | reward=+3.82 | profit=+39.01€ | sat=21.4% | overload=0.00kWh | Qlost=0.00022 | EVs=3
#   [Phase1_HP_only] Ep  4 | reward=+49.47 | profit=+108.13€ | sat=21.4% | overload=0.00kWh | Qlost=0.00042 | EVs=5
#   [Phase1_HP_only] Ep  5 | reward=+66.17 | profit=+148.29€ | sat=21.4% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Phase1_HP_only] Ep  6 | reward=+29.02 | profit=+87.68€ | sat=21.4% | overload=0.00kWh | Qlost=0.00042 | EVs=5
#   [Phase1_HP_only] Ep  7 | reward=+41.24 | profit=+88.17€ | sat=21.4% | overload=0.00kWh | Qlost=0.00030 | EVs=4
#   [Phase1_HP_only] Ep  8 | reward=+12.55 | profit=+15.70€ | sat=55.1% | overload=0.00kWh | Qlost=0.00016 | EVs=3
#   [Phase1_HP_only] Ep  9 | reward=+4.02 | profit=+14.44€ | sat=45.0% | overload=0.00kWh | Qlost=0.00023 | EVs=6
#   [Phase1_HP_only] Ep 10 | reward=+9.55 | profit=+17.35€ | sat=44.4% | overload=0.00kWh | Qlost=0.00020 | EVs=5
#   [Phase1_HP_only] Ep 11 | reward=+3.00 | profit=+4.47€ | sat=50.8% | overload=0.00kWh | Qlost=0.00007 | EVs=2
#   [Phase1_HP_only] Ep 12 | reward=+1.67 | profit=+6.26€ | sat=53.8% | overload=0.00kWh | Qlost=0.00017 | EVs=5
#   [Phase1_HP_only] Ep 13 | reward=+13.53 | profit=+77.03€ | sat=25.3% | overload=0.00kWh | Qlost=0.00049 | EVs=7
#   [Phase1_HP_only] Ep 14 | reward=-0.28 | profit=+9.16€ | sat=47.0% | overload=0.00kWh | Qlost=0.00018 | EVs=4
#   [Phase1_HP_only] Ep 15 | reward=+16.96 | profit=+21.14€ | sat=49.5% | overload=0.00kWh | Qlost=0.00022 | EVs=5
#   [Phase1_HP_only] Ep 16 | reward=+4.79 | profit=+16.87€ | sat=45.2% | overload=0.00kWh | Qlost=0.00027 | EVs=6
#   [Phase1_HP_only] Ep 17 | reward=+1.29 | profit=+2.89€ | sat=56.3% | overload=0.00kWh | Qlost=0.00014 | EVs=4
#   [Phase1_HP_only] Ep 18 | reward=+5.78 | profit=+63.30€ | sat=26.3% | overload=0.00kWh | Qlost=0.00039 | EVs=6
#   [Phase1_HP_only] Ep 19 | reward=+13.45 | profit=+50.25€ | sat=31.5% | overload=0.00kWh | Qlost=0.00037 | EVs=6
#   [Phase1_HP_only] Ep 20 | reward=+4.20 | profit=+6.20€ | sat=51.8% | overload=0.00kWh | Qlost=0.00014 | EVs=3
#   [Phase1_HP_only] Ep 21 | reward=+16.86 | profit=+41.17€ | sat=36.1% | overload=0.00kWh | Qlost=0.00035 | EVs=6
#   [Phase1_HP_only] Ep 22 | reward=+2.91 | profit=+19.75€ | sat=35.1% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Phase1_HP_only] Ep 23 | reward=-2.06 | profit=+9.67€ | sat=21.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Phase1_HP_only] Ep 24 | reward=+0.59 | profit=+35.08€ | sat=26.4% | overload=0.00kWh | Qlost=0.00026 | EVs=4
#   [Phase1_HP_only] Ep 25 | reward=+11.37 | profit=+18.41€ | sat=52.7% | overload=0.00kWh | Qlost=0.00029 | EVs=7
#   [Phase1_HP_only] Ep 26 | reward=+17.29 | profit=+51.52€ | sat=34.0% | overload=0.00kWh | Qlost=0.00043 | EVs=7
#   [Phase1_HP_only] Ep 27 | reward=+1.19 | profit=+2.10€ | sat=65.5% | overload=0.00kWh | Qlost=0.00011 | EVs=4
#   [Phase1_HP_only] Ep 28 | reward=+21.48 | profit=+101.27€ | sat=21.7% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Phase1_HP_only] Ep 29 | reward=-0.73 | profit=+42.79€ | sat=35.6% | overload=0.00kWh | Qlost=0.00047 | EVs=8
#   [Phase1_HP_only] Ep 30 | reward=-7.01 | profit=+4.72€ | sat=21.4% | overload=0.00kWh | Qlost=0.00004 | EVs=1
#   [Phase1_HP_only] Ep 31 | reward=+3.48 | profit=+28.18€ | sat=32.6% | overload=0.00kWh | Qlost=0.00027 | EVs=5
#   [Phase1_HP_only] Ep 32 | reward=+11.86 | profit=+26.01€ | sat=41.6% | overload=0.00kWh | Qlost=0.00024 | EVs=5
#   [Phase1_HP_only] Ep 33 | reward=-17.10 | profit=+23.72€ | sat=23.3% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Phase1_HP_only] Ep 34 | reward=+7.67 | profit=+48.93€ | sat=33.9% | overload=0.00kWh | Qlost=0.00042 | EVs=8
#   [Phase1_HP_only] Ep 35 | reward=+47.56 | profit=+106.22€ | sat=21.4% | overload=0.00kWh | Qlost=0.00037 | EVs=5
#   [Phase1_HP_only] Ep 36 | reward=+7.46 | profit=+24.11€ | sat=42.4% | overload=0.00kWh | Qlost=0.00026 | EVs=7
#   [Phase1_HP_only] Ep 37 | reward=+1.11 | profit=+24.82€ | sat=34.3% | overload=0.00kWh | Qlost=0.00020 | EVs=3
#   [Phase1_HP_only] Ep 38 | reward=+4.53 | profit=+7.15€ | sat=61.3% | overload=0.00kWh | Qlost=0.00019 | EVs=6
#   [Phase1_HP_only] Ep 39 | reward=+2.32 | profit=+37.19€ | sat=27.7% | overload=0.00kWh | Qlost=0.00032 | EVs=5
#   [Phase1_HP_only] Ep 40 | reward=+8.87 | profit=+43.35€ | sat=31.6% | overload=0.00kWh | Qlost=0.00035 | EVs=6
#   [Phase1_HP_only] Ep 41 | reward=+5.68 | profit=+13.07€ | sat=48.4% | overload=0.00kWh | Qlost=0.00027 | EVs=6
#   [Phase1_HP_only] Ep 42 | reward=+54.69 | profit=+136.08€ | sat=21.5% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Phase1_HP_only] Ep 43 | reward=+4.79 | profit=+6.87€ | sat=53.5% | overload=0.00kWh | Qlost=0.00013 | EVs=4
#   [Phase1_HP_only] Ep 44 | reward=+0.78 | profit=+17.93€ | sat=40.0% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Phase1_HP_only] Ep 45 | reward=-0.59 | profit=+5.99€ | sat=42.9% | overload=0.00kWh | Qlost=0.00011 | EVs=3
#   [Phase1_HP_only] Ep 46 | reward=+7.24 | profit=+13.44€ | sat=51.6% | overload=0.00kWh | Qlost=0.00033 | EVs=7
#   [Phase1_HP_only] Ep 47 | reward=+7.28 | profit=+31.40€ | sat=50.4% | overload=0.00kWh | Qlost=0.00025 | EVs=5
#   [Phase1_HP_only] Ep 48 | reward=+3.93 | profit=+6.57€ | sat=58.7% | overload=0.00kWh | Qlost=0.00024 | EVs=8
#   [Phase1_HP_only] Ep 49 | reward=+6.68 | profit=+9.44€ | sat=67.7% | overload=0.00kWh | Qlost=0.00024 | EVs=6
#   [Phase1_HP_only] Ep 50 | reward=+7.62 | profit=+11.46€ | sat=57.3% | overload=0.00kWh | Qlost=0.00030 | EVs=7
#   [Phase1_HP_only] Ep 51 | reward=+98.28 | profit=+182.07€ | sat=23.9% | overload=0.00kWh | Qlost=0.00063 | EVs=8
#   [Phase1_HP_only] Ep 52 | reward=+21.42 | profit=+68.34€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Phase1_HP_only] Ep 53 | reward=+0.38 | profit=+3.17€ | sat=61.9% | overload=0.00kWh | Qlost=0.00017 | EVs=7
#   [Phase1_HP_only] Ep 54 | reward=+4.19 | profit=+16.47€ | sat=50.7% | overload=0.00kWh | Qlost=0.00034 | EVs=7
#   [Phase1_HP_only] Ep 55 | reward=+5.99 | profit=+70.48€ | sat=25.7% | overload=0.00kWh | Qlost=0.00051 | EVs=7
#   [Phase1_HP_only] Ep 56 | reward=+1.63 | profit=+2.02€ | sat=76.9% | overload=0.00kWh | Qlost=0.00020 | EVs=6
#   [Phase1_HP_only] Ep 57 | reward=-7.66 | profit=+10.80€ | sat=35.2% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Phase1_HP_only] Ep 58 | reward=+15.09 | profit=+29.12€ | sat=43.0% | overload=0.00kWh | Qlost=0.00031 | EVs=7
#   [Phase1_HP_only] Ep 59 | reward=-8.10 | profit=+50.56€ | sat=21.4% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Phase1_HP_only] Ep 60 | reward=+10.32 | profit=+59.19€ | sat=25.7% | overload=0.00kWh | Qlost=0.00044 | EVs=6
#   [Phase1_HP_only] Ep 61 | reward=+4.73 | profit=+5.15€ | sat=79.6% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Phase1_HP_only] Ep 62 | reward=+4.66 | profit=+24.74€ | sat=36.2% | overload=0.00kWh | Qlost=0.00019 | EVs=3
#   [Phase1_HP_only] Ep 63 | reward=+9.62 | profit=+56.55€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Phase1_HP_only] Ep 64 | reward=+34.00 | profit=+104.39€ | sat=21.4% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Phase1_HP_only] Ep 65 | reward=+6.60 | profit=+12.24€ | sat=41.1% | overload=0.00kWh | Qlost=0.00015 | EVs=3
#   [Phase1_HP_only] Ep 66 | reward=+17.36 | profit=+23.16€ | sat=48.1% | overload=0.00kWh | Qlost=0.00026 | EVs=6
#   [Phase1_HP_only] Ep 67 | reward=+17.18 | profit=+45.30€ | sat=40.7% | overload=0.00kWh | Qlost=0.00045 | EVs=9
#   [Phase1_HP_only] Ep 68 | reward=+8.63 | profit=+27.30€ | sat=38.4% | overload=0.00kWh | Qlost=0.00028 | EVs=5
#   [Phase1_HP_only] Ep 69 | reward=+13.02 | profit=+20.96€ | sat=47.7% | overload=0.00kWh | Qlost=0.00028 | EVs=6
#   [Phase1_HP_only] Ep 70 | reward=+4.38 | profit=+21.77€ | sat=25.1% | overload=0.00kWh | Qlost=0.00015 | EVs=2
#   [Phase1_HP_only] Ep 71 | reward=+0.21 | profit=+1.30€ | sat=59.9% | overload=0.00kWh | Qlost=0.00010 | EVs=3
#   [Phase1_HP_only] Ep 72 | reward=-4.50 | profit=+30.70€ | sat=21.4% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#   [Phase1_HP_only] Ep 73 | reward=+22.89 | profit=+81.55€ | sat=21.4% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Phase1_HP_only] Ep 74 | reward=+2.41 | profit=+9.88€ | sat=43.2% | overload=0.00kWh | Qlost=0.00018 | EVs=4
#   [Phase1_HP_only] Ep 75 | reward=-5.41 | profit=+49.46€ | sat=22.2% | overload=0.00kWh | Qlost=0.00035 | EVs=5
#   [Phase1_HP_only] Ep 76 | reward=+3.05 | profit=+29.26€ | sat=39.3% | overload=0.00kWh | Qlost=0.00033 | EVs=6
#   [Phase1_HP_only] Ep 77 | reward=+1.13 | profit=+5.43€ | sat=53.0% | overload=0.00kWh | Qlost=0.00014 | EVs=4
#   [Phase1_HP_only] Ep 78 | reward=-4.78 | profit=+65.61€ | sat=21.4% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Phase1_HP_only] Ep 79 | reward=-4.76 | profit=+12.90€ | sat=45.3% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Phase1_HP_only] Ep 80 | reward=-0.23 | profit=+11.84€ | sat=39.2% | overload=0.00kWh | Qlost=0.00012 | EVs=2
#   [Phase1_HP_only] Ep 81 | reward=+4.20 | profit=+16.61€ | sat=39.1% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Phase1_HP_only] Ep 82 | reward=+7.53 | profit=+9.69€ | sat=56.8% | overload=0.00kWh | Qlost=0.00016 | EVs=4
#   [Phase1_HP_only] Ep 83 | reward=+36.83 | profit=+83.76€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Phase1_HP_only] Ep 84 | reward=+1.04 | profit=+1.35€ | sat=57.8% | overload=0.00kWh | Qlost=0.00002 | EVs=1
#   [Phase1_HP_only] Ep 85 | reward=+4.56 | profit=+8.35€ | sat=32.7% | overload=0.00kWh | Qlost=0.00006 | EVs=1
#   [Phase1_HP_only] Ep 86 | reward=+12.70 | profit=+45.78€ | sat=34.0% | overload=0.00kWh | Qlost=0.00034 | EVs=6
#   [Phase1_HP_only] Ep 87 | reward=+12.46 | profit=+23.36€ | sat=42.9% | overload=0.00kWh | Qlost=0.00026 | EVs=6
#   [Phase1_HP_only] Ep 88 | reward=+4.91 | profit=+8.99€ | sat=46.1% | overload=0.00kWh | Qlost=0.00015 | EVs=4
#   [Phase1_HP_only] Ep 89 | reward=+10.87 | profit=+72.62€ | sat=26.1% | overload=0.00kWh | Qlost=0.00044 | EVs=7
#   [Phase1_HP_only] Ep 90 | reward=+2.38 | profit=+16.18€ | sat=32.4% | overload=0.00kWh | Qlost=0.00023 | EVs=3
#   [Phase1_HP_only] Ep 91 | reward=+3.43 | profit=+61.47€ | sat=26.1% | overload=0.00kWh | Qlost=0.00045 | EVs=6
#   [Phase1_HP_only] Ep 92 | reward=+4.77 | profit=+26.40€ | sat=35.9% | overload=0.00kWh | Qlost=0.00024 | EVs=4
#   [Phase1_HP_only] Ep 93 | reward=-14.02 | profit=+42.11€ | sat=24.9% | overload=0.00kWh | Qlost=0.00032 | EVs=6
#   [Phase1_HP_only] Ep 94 | reward=+62.26 | profit=+132.66€ | sat=21.4% | overload=0.00kWh | Qlost=0.00050 | EVs=6
#   [Phase1_HP_only] Ep 95 | reward=-3.76 | profit=+27.15€ | sat=29.0% | overload=0.00kWh | Qlost=0.00023 | EVs=4
#   [Phase1_HP_only] Ep 96 | reward=-2.18 | profit=+16.49€ | sat=41.6% | overload=0.00kWh | Qlost=0.00023 | EVs=5
#   [Phase1_HP_only] Ep 97 | reward=+6.76 | profit=+30.22€ | sat=21.4% | overload=0.00kWh | Qlost=0.00014 | EVs=2
#   [Phase1_HP_only] Ep 98 | reward=+13.50 | profit=+60.43€ | sat=21.4% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Phase1_HP_only] Ep 99 | reward=+6.24 | profit=+20.08€ | sat=45.4% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Phase1_HP_only] Ep 100 | reward=+1.25 | profit=+36.45€ | sat=21.4% | overload=0.00kWh | Qlost=0.00023 | EVs=3
#
# Evaluating Phase 2...
#   [Phase2_HP_YAML] Ep  1 | reward=+11.03 | profit=+39.11€ | sat=28.4% | overload=0.00kWh | Qlost=0.00035 | EVs=4
#   [Phase2_HP_YAML] Ep  2 | reward=+1.27 | profit=+13.45€ | sat=50.9% | overload=0.00kWh | Qlost=0.00035 | EVs=4
#   [Phase2_HP_YAML] Ep  3 | reward=+23.37 | profit=+58.57€ | sat=21.4% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#   [Phase2_HP_YAML] Ep  4 | reward=+89.56 | profit=+137.51€ | sat=26.3% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Phase2_HP_YAML] Ep  5 | reward=+147.42 | profit=+203.05€ | sat=29.2% | overload=0.00kWh | Qlost=0.00057 | EVs=7
#   [Phase2_HP_YAML] Ep  6 | reward=+75.76 | profit=+123.74€ | sat=26.2% | overload=0.00kWh | Qlost=0.00049 | EVs=5
#   [Phase2_HP_YAML] Ep  7 | reward=+83.64 | profit=+130.56€ | sat=21.4% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Phase2_HP_YAML] Ep  8 | reward=-13.46 | profit=+16.39€ | sat=23.5% | overload=0.00kWh | Qlost=0.00030 | EVs=3
#   [Phase2_HP_YAML] Ep  9 | reward=-3.29 | profit=+29.38€ | sat=34.2% | overload=0.00kWh | Qlost=0.00051 | EVs=6
#   [Phase2_HP_YAML] Ep 10 | reward=+4.95 | profit=+31.14€ | sat=44.0% | overload=0.00kWh | Qlost=0.00051 | EVs=5
#   [Phase2_HP_YAML] Ep 11 | reward=+7.67 | profit=+8.70€ | sat=53.2% | overload=0.00kWh | Qlost=0.00022 | EVs=2
#   [Phase2_HP_YAML] Ep 12 | reward=-11.08 | profit=+14.19€ | sat=39.4% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Phase2_HP_YAML] Ep 13 | reward=+59.69 | profit=+121.22€ | sat=29.4% | overload=0.00kWh | Qlost=0.00060 | EVs=7
#   [Phase2_HP_YAML] Ep 14 | reward=+1.62 | profit=+19.61€ | sat=38.0% | overload=0.00kWh | Qlost=0.00037 | EVs=4
#   [Phase2_HP_YAML] Ep 15 | reward=+8.16 | profit=+20.11€ | sat=72.6% | overload=0.00kWh | Qlost=0.00059 | EVs=5
#   [Phase2_HP_YAML] Ep 16 | reward=+8.84 | profit=+38.79€ | sat=34.1% | overload=0.00kWh | Qlost=0.00056 | EVs=6
#   [Phase2_HP_YAML] Ep 17 | reward=-20.10 | profit=+6.36€ | sat=29.7% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Phase2_HP_YAML] Ep 18 | reward=+42.28 | profit=+107.45€ | sat=22.3% | overload=0.00kWh | Qlost=0.00054 | EVs=6
#   [Phase2_HP_YAML] Ep 19 | reward=+47.95 | profit=+61.79€ | sat=54.4% | overload=0.00kWh | Qlost=0.00058 | EVs=6
#   [Phase2_HP_YAML] Ep 20 | reward=-25.04 | profit=+9.85€ | sat=21.5% | overload=0.00kWh | Qlost=0.00025 | EVs=3
#   [Phase2_HP_YAML] Ep 21 | reward=+15.96 | profit=+69.36€ | sat=27.1% | overload=0.00kWh | Qlost=0.00059 | EVs=6
#   [Phase2_HP_YAML] Ep 22 | reward=+7.95 | profit=+38.10€ | sat=27.7% | overload=0.00kWh | Qlost=0.00034 | EVs=4
#   [Phase2_HP_YAML] Ep 23 | reward=+2.74 | profit=+14.47€ | sat=21.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Phase2_HP_YAML] Ep 24 | reward=+9.63 | profit=+48.59€ | sat=24.3% | overload=0.00kWh | Qlost=0.00034 | EVs=4
#   [Phase2_HP_YAML] Ep 25 | reward=-4.99 | profit=+36.03€ | sat=36.7% | overload=0.00kWh | Qlost=0.00084 | EVs=7
#   [Phase2_HP_YAML] Ep 26 | reward=+5.35 | profit=+81.57€ | sat=22.5% | overload=0.00kWh | Qlost=0.00062 | EVs=7
#   [Phase2_HP_YAML] Ep 27 | reward=-32.09 | profit=+11.19€ | sat=22.4% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Phase2_HP_YAML] Ep 28 | reward=+64.84 | profit=+136.79€ | sat=23.3% | overload=0.00kWh | Qlost=0.00049 | EVs=7
#   [Phase2_HP_YAML] Ep 29 | reward=+28.60 | profit=+65.59€ | sat=45.6% | overload=0.00kWh | Qlost=0.00094 | EVs=8
#   [Phase2_HP_YAML] Ep 30 | reward=-4.00 | profit=+7.22€ | sat=21.9% | overload=0.00kWh | Qlost=0.00005 | EVs=1
#   [Phase2_HP_YAML] Ep 31 | reward=+3.38 | profit=+57.36€ | sat=22.3% | overload=0.00kWh | Qlost=0.00040 | EVs=5
#   [Phase2_HP_YAML] Ep 32 | reward=+25.44 | profit=+52.87€ | sat=35.5% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Phase2_HP_YAML] Ep 33 | reward=+0.65 | profit=+31.48€ | sat=28.1% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Phase2_HP_YAML] Ep 34 | reward=+24.80 | profit=+56.18€ | sat=50.2% | overload=0.00kWh | Qlost=0.00071 | EVs=8
#   [Phase2_HP_YAML] Ep 35 | reward=+100.98 | profit=+159.10€ | sat=21.5% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Phase2_HP_YAML] Ep 36 | reward=+16.13 | profit=+55.06€ | sat=33.1% | overload=0.00kWh | Qlost=0.00053 | EVs=7
#   [Phase2_HP_YAML] Ep 37 | reward=+23.10 | profit=+38.64€ | sat=37.6% | overload=0.00kWh | Qlost=0.00032 | EVs=3
#   [Phase2_HP_YAML] Ep 38 | reward=+5.16 | profit=+17.62€ | sat=59.9% | overload=0.00kWh | Qlost=0.00084 | EVs=6
#   [Phase2_HP_YAML] Ep 39 | reward=+9.10 | profit=+62.34€ | sat=22.7% | overload=0.00kWh | Qlost=0.00044 | EVs=5
#   [Phase2_HP_YAML] Ep 40 | reward=+17.90 | profit=+68.08€ | sat=28.1% | overload=0.00kWh | Qlost=0.00050 | EVs=6
#   [Phase2_HP_YAML] Ep 41 | reward=-2.21 | profit=+22.04€ | sat=51.0% | overload=0.00kWh | Qlost=0.00074 | EVs=6
#   [Phase2_HP_YAML] Ep 42 | reward=+131.60 | profit=+197.11€ | sat=27.0% | overload=0.00kWh | Qlost=0.00056 | EVs=7
#   [Phase2_HP_YAML] Ep 43 | reward=-13.17 | profit=+20.80€ | sat=29.0% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Phase2_HP_YAML] Ep 44 | reward=-26.21 | profit=+9.00€ | sat=37.4% | overload=0.00kWh | Qlost=0.00036 | EVs=4
#   [Phase2_HP_YAML] Ep 45 | reward=-3.59 | profit=+11.71€ | sat=30.3% | overload=0.00kWh | Qlost=0.00020 | EVs=3
#   [Phase2_HP_YAML] Ep 46 | reward=-27.27 | profit=+27.78€ | sat=30.7% | overload=0.00kWh | Qlost=0.00067 | EVs=7
#   [Phase2_HP_YAML] Ep 47 | reward=-0.27 | profit=+40.20€ | sat=27.9% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Phase2_HP_YAML] Ep 48 | reward=+4.90 | profit=+23.65€ | sat=48.4% | overload=0.00kWh | Qlost=0.00083 | EVs=8
#   [Phase2_HP_YAML] Ep 49 | reward=-35.01 | profit=+24.52€ | sat=23.6% | overload=0.00kWh | Qlost=0.00053 | EVs=6
#   [Phase2_HP_YAML] Ep 50 | reward=-7.41 | profit=+24.81€ | sat=52.6% | overload=0.00kWh | Qlost=0.00084 | EVs=7
#   [Phase2_HP_YAML] Ep 51 | reward=+187.87 | profit=+261.26€ | sat=27.1% | overload=0.00kWh | Qlost=0.00071 | EVs=8
#   [Phase2_HP_YAML] Ep 52 | reward=+47.70 | profit=+94.63€ | sat=21.4% | overload=0.00kWh | Qlost=0.00034 | EVs=4
#   [Phase2_HP_YAML] Ep 53 | reward=-2.29 | profit=+4.99€ | sat=56.2% | overload=0.00kWh | Qlost=0.00058 | EVs=7
#   [Phase2_HP_YAML] Ep 54 | reward=-54.12 | profit=-24.17€ | sat=44.3% | overload=0.00kWh | Qlost=0.00074 | EVs=7
#   [Phase2_HP_YAML] Ep 55 | reward=+41.83 | profit=+107.51€ | sat=26.0% | overload=0.00kWh | Qlost=0.00061 | EVs=7
#   [Phase2_HP_YAML] Ep 56 | reward=-13.65 | profit=+8.30€ | sat=52.6% | overload=0.00kWh | Qlost=0.00058 | EVs=6
#   [Phase2_HP_YAML] Ep 57 | reward=-15.21 | profit=+10.21€ | sat=31.7% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Phase2_HP_YAML] Ep 58 | reward=+14.54 | profit=+27.40€ | sat=64.1% | overload=0.00kWh | Qlost=0.00090 | EVs=7
#   [Phase2_HP_YAML] Ep 59 | reward=+19.06 | profit=+77.72€ | sat=21.4% | overload=0.00kWh | Qlost=0.00035 | EVs=5
#   [Phase2_HP_YAML] Ep 60 | reward=+40.50 | profit=+92.70€ | sat=24.8% | overload=0.00kWh | Qlost=0.00059 | EVs=6
#   [Phase2_HP_YAML] Ep 61 | reward=-40.45 | profit=-19.41€ | sat=52.2% | overload=0.00kWh | Qlost=0.00093 | EVs=7
#   [Phase2_HP_YAML] Ep 62 | reward=+17.18 | profit=+42.45€ | sat=27.7% | overload=0.00kWh | Qlost=0.00029 | EVs=3
#   [Phase2_HP_YAML] Ep 63 | reward=+25.40 | profit=+72.33€ | sat=21.4% | overload=0.00kWh | Qlost=0.00038 | EVs=4
#   [Phase2_HP_YAML] Ep 64 | reward=+88.81 | profit=+153.91€ | sat=22.4% | overload=0.00kWh | Qlost=0.00049 | EVs=6
#   [Phase2_HP_YAML] Ep 65 | reward=+4.15 | profit=+24.50€ | sat=33.1% | overload=0.00kWh | Qlost=0.00028 | EVs=3
#   [Phase2_HP_YAML] Ep 66 | reward=+17.35 | profit=+47.85€ | sat=40.3% | overload=0.00kWh | Qlost=0.00066 | EVs=6
#   [Phase2_HP_YAML] Ep 67 | reward=-12.47 | profit=+76.72€ | sat=23.6% | overload=0.00kWh | Qlost=0.00086 | EVs=9
#   [Phase2_HP_YAML] Ep 68 | reward=-6.79 | profit=+45.33€ | sat=22.7% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Phase2_HP_YAML] Ep 69 | reward=-1.32 | profit=+37.72€ | sat=40.5% | overload=0.00kWh | Qlost=0.00063 | EVs=6
#   [Phase2_HP_YAML] Ep 70 | reward=+12.16 | profit=+35.62€ | sat=21.4% | overload=0.00kWh | Qlost=0.00018 | EVs=2
#   [Phase2_HP_YAML] Ep 71 | reward=-5.76 | profit=+7.23€ | sat=39.9% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#   [Phase2_HP_YAML] Ep 72 | reward=+16.05 | profit=+40.65€ | sat=26.0% | overload=0.00kWh | Qlost=0.00027 | EVs=3
#   [Phase2_HP_YAML] Ep 73 | reward=+67.35 | profit=+114.08€ | sat=24.5% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Phase2_HP_YAML] Ep 74 | reward=+4.03 | profit=+20.22€ | sat=37.3% | overload=0.00kWh | Qlost=0.00035 | EVs=4
#   [Phase2_HP_YAML] Ep 75 | reward=+10.42 | profit=+69.08€ | sat=21.4% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Phase2_HP_YAML] Ep 76 | reward=-1.50 | profit=+59.15€ | sat=23.2% | overload=0.00kWh | Qlost=0.00049 | EVs=6
#   [Phase2_HP_YAML] Ep 77 | reward=-29.30 | profit=+17.62€ | sat=21.4% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Phase2_HP_YAML] Ep 78 | reward=+19.88 | profit=+82.76€ | sat=22.7% | overload=0.00kWh | Qlost=0.00048 | EVs=6
#   [Phase2_HP_YAML] Ep 79 | reward=-29.54 | profit=+34.84€ | sat=33.6% | overload=0.00kWh | Qlost=0.00065 | EVs=7
#   [Phase2_HP_YAML] Ep 80 | reward=-1.24 | profit=+22.22€ | sat=21.4% | overload=0.00kWh | Qlost=0.00019 | EVs=2
#   [Phase2_HP_YAML] Ep 81 | reward=-3.93 | profit=+34.72€ | sat=23.5% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Phase2_HP_YAML] Ep 82 | reward=-4.04 | profit=+29.72€ | sat=25.5% | overload=0.00kWh | Qlost=0.00039 | EVs=4
#   [Phase2_HP_YAML] Ep 83 | reward=+81.86 | profit=+121.25€ | sat=24.0% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Phase2_HP_YAML] Ep 84 | reward=-5.94 | profit=+5.79€ | sat=21.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Phase2_HP_YAML] Ep 85 | reward=+3.65 | profit=+15.38€ | sat=21.4% | overload=0.00kWh | Qlost=0.00008 | EVs=1
#   [Phase2_HP_YAML] Ep 86 | reward=+16.93 | profit=+77.05€ | sat=23.3% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Phase2_HP_YAML] Ep 87 | reward=+19.19 | profit=+57.22€ | sat=33.4% | overload=0.00kWh | Qlost=0.00061 | EVs=6
#   [Phase2_HP_YAML] Ep 88 | reward=-16.25 | profit=+25.49€ | sat=22.7% | overload=0.00kWh | Qlost=0.00030 | EVs=4
#   [Phase2_HP_YAML] Ep 89 | reward=+12.31 | profit=+94.09€ | sat=21.5% | overload=0.00kWh | Qlost=0.00054 | EVs=7
#   [Phase2_HP_YAML] Ep 90 | reward=+3.58 | profit=+11.54€ | sat=64.7% | overload=0.00kWh | Qlost=0.00038 | EVs=3
#   [Phase2_HP_YAML] Ep 91 | reward=+27.84 | profit=+68.29€ | sat=32.8% | overload=0.00kWh | Qlost=0.00059 | EVs=6
#   [Phase2_HP_YAML] Ep 92 | reward=+14.55 | profit=+38.31€ | sat=32.5% | overload=0.00kWh | Qlost=0.00036 | EVs=4
#   [Phase2_HP_YAML] Ep 93 | reward=+11.50 | profit=+63.86€ | sat=26.4% | overload=0.00kWh | Qlost=0.00043 | EVs=6
#   [Phase2_HP_YAML] Ep 94 | reward=+139.18 | profit=+189.12€ | sat=28.4% | overload=0.00kWh | Qlost=0.00053 | EVs=6
#   [Phase2_HP_YAML] Ep 95 | reward=+10.84 | profit=+40.91€ | sat=28.4% | overload=0.00kWh | Qlost=0.00031 | EVs=4
#   [Phase2_HP_YAML] Ep 96 | reward=-6.53 | profit=+27.86€ | sat=32.5% | overload=0.00kWh | Qlost=0.00037 | EVs=5
#   [Phase2_HP_YAML] Ep 97 | reward=+11.02 | profit=+34.48€ | sat=21.4% | overload=0.00kWh | Qlost=0.00014 | EVs=2
#   [Phase2_HP_YAML] Ep 98 | reward=+40.74 | profit=+81.29€ | sat=23.4% | overload=0.00kWh | Qlost=0.00038 | EVs=4
#   [Phase2_HP_YAML] Ep 99 | reward=+14.20 | profit=+31.36€ | sat=46.9% | overload=0.00kWh | Qlost=0.00058 | EVs=7
#   [Phase2_HP_YAML] Ep 100 | reward=+25.45 | profit=+52.51€ | sat=25.4% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#
# Total: 200 episodes

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Summary statistics (Table VII format)
# ─────────────────────────────────────────────────────────────────────────────

def summarise(episodes: list, label: str) -> "pd.DataFrame":
    """
    Computes mean ± std and full distribution stats.

    STATISTICAL NOTE: When std >= mean, pairwise between-algorithm differences
    may not be statistically significant. Bootstrap CIs or Wilcoxon signed-rank
    tests are recommended (Agarwal et al., NeurIPS 2021). std_exceeds_mean flag
    highlights these cases. p95 and iqr support distributional analysis.
    """
    df = pd.DataFrame([{k: v for k, v in e.items() if k in SCALAR_COLS} for e in episodes])
    rows = []
    for col in SCALAR_COLS:
        if col not in df.columns: continue
        s = df[col]
        n = len(s)
        std = s.std(ddof=1) if n > 1 else 0.0
        rows.append({
            "algorithm": label, "metric": col, "n": n,
            "mean": s.mean(), "std": std,
            "std_exceeds_mean": abs(std) > abs(s.mean()) if s.mean() != 0 else False,
            "min": s.min(), "p25": s.quantile(0.25),
            "median": s.median(), "p75": s.quantile(0.75),
            "p95": s.quantile(0.95), "max": s.max(),
            "iqr": s.quantile(0.75) - s.quantile(0.25),
        })
    return pd.DataFrame(rows)

df_sum_p1  = summarise(eps_p1, "Phase1")
df_sum_p2  = summarise(eps_p2, "Phase2")
df_all_sum = pd.concat([df_sum_p1, df_sum_p2], ignore_index=True)

TABLE7 = [
    ("total_profit_cost",        "Profit/Cost (€)   ", 1),
    ("user_satisfaction",        "User sat. (%)       ", 100),
    ("energy_charged_kwh",       "E_ch (kWh)          ", 1),
    ("energy_discharged_kwh",    "E_dis (kWh)         ", 1),
    ("transformer_overload_kwh", "Overload ε_ov (kWh) ", 1),
    ("battery_degradation",      "Q_lost (×10⁻³)      ", 1e3),
    ("exec_time_s",              "Exec time (s)       ", 1),
    ("reward_total",             "Reward              ", 1),
]
print("=" * 72)
print("  TABLA VII — mean ± std")
print("=" * 72)
for col, lbl, mult in TABLE7:
    sub = df_all_sum[df_all_sum["metric"] == col]
    print(f"\n  {lbl}")
    for _, r in sub.iterrows():
        print(f"    {r['algorithm']:<12} {r['mean']*mult:+10.3f} ± {r['std']*mult:.3f}"
              f"  [{r['min']*mult:+.2f}, {r['max']*mult:+.2f}]")
# Out:
# ========================================================================
#   TABLA VII — mean ± std
# ========================================================================
#
#   Profit/Cost (€)
#     Phase1          +36.260 ± 35.506  [+1.30, +182.07]
#     Phase2          +54.459 ± 49.914  [-24.17, +261.26]
#
#   User sat. (%)
#     Phase1          +37.974 ± 14.217  [+21.43, +79.57]
#     Phase2          +31.964 ± 11.802  [+21.43, +72.64]
#
#   E_ch (kWh)
#     Phase1           +5.329 ± 9.401  [+0.00, +56.84]
#     Phase2          +46.065 ± 53.020  [+0.00, +223.48]
#
#   E_dis (kWh)
#     Phase1         +144.800 ± 69.589  [+12.64, +332.42]
#     Phase2         +204.093 ± 76.176  [+27.37, +388.85]
#
#   Overload ε_ov (kWh)
#     Phase1           +0.000 ± 0.000  [+0.00, +0.00]
#     Phase2           +0.000 ± 0.000  [+0.00, +0.00]
#
#   Q_lost (×10⁻³)
#     Phase1           +0.273 ± 0.123  [+0.02, +0.63]
#     Phase2           +0.453 ± 0.198  [+0.05, +0.94]
#
#   Exec time (s)
#     Phase1           +5.033 ± 0.662  [+2.75, +6.99]
#     Phase2           +6.158 ± 0.506  [+5.16, +7.58]
#
#   Reward
#     Phase1           +9.817 ± 16.854  [-17.10, +98.28]
#     Phase2          +16.991 ± 39.854  [-54.12, +187.87]

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Congestion and operating-regime analysis
# ─────────────────────────────────────────────────────────────────────────────

def analyse_episodes(episodes: list, label: str) -> "pd.DataFrame":
    df = pd.DataFrame([{k: v for k, v in e.items()
                        if k in SCALAR_COLS + ["episode","seed","phase"]}
                       for e in episodes])
    df["congested"]  = df["transformer_overload_kwh"] > 0
    df["high_sat"]   = df["user_satisfaction"] >= 0.8
    df["profitable"] = df["total_profit_cost"] > 0
    if len(df) >= 3:
        q33 = df["reward_total"].quantile(0.33)
        q66 = df["reward_total"].quantile(0.66)
        df["regime"] = pd.cut(df["reward_total"],
                              bins=[-np.inf, q33, q66, np.inf],
                              labels=["Conservative","Balanced","Aggressive"])
    print(f"[{label}] congested={df['congested'].sum()}/{len(df)} | "
          f"sat>=80%={df['high_sat'].sum()}/{len(df)} | "
          f"profitable={df['profitable'].sum()}/{len(df)}")
    return df

df_eps_p1 = analyse_episodes(eps_p1, "Phase1")
df_eps_p2 = analyse_episodes(eps_p2, "Phase2")
# Out:
# [Phase1] congested=0/100 | sat>=80%=0/100 | profitable=100/100
# [Phase2] congested=0/100 | sat>=80%=0/100 | profitable=98/100

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Boxplots + traces and Pareto front
# ─────────────────────────────────────────────────────────────────────────────

def get_col(eps, col): return [e[col] for e in eps]

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
colors = ["steelblue", "darkorange"]
labels_box = ["Phase 1\n(HPs)", "Phase 2\n(HPs+YAML)"]
metrics_box = [
    ("reward_total",             "Reward",           "€",      1,   False),
    ("total_profit_cost",        "Profit/Costs",     "€",      1,   False),
    ("user_satisfaction",        "User sat. ε_usr",  "%",      100, True),
    ("transformer_overload_kwh", "Overload ε_ov",    "kWh",    1,   False),
    ("energy_discharged_kwh",    "E_dis (V2G)",      "kWh",    1,   False),
    ("battery_degradation",      "Q_lost",           "×10⁻³", 1e3, False),
]
for ax, (col, title, unit, mult, is_sat) in zip(axes.flat, metrics_box):
    data = [[v*mult for v in get_col(eps_p1,col)],
            [v*mult for v in get_col(eps_p2,col)]]
    bp = ax.boxplot(data, labels=labels_box, patch_artist=True,
                    medianprops=dict(color="black", linewidth=2))
    for patch, c in zip(bp["boxes"], colors):
        patch.set_facecolor(c); patch.set_alpha(0.65)
    ax.axhline(0, color="gray", ls="--", lw=0.8)
    if is_sat: ax.set_ylim(0,105)
    ax.set_title(title, fontweight="bold"); ax.set_ylabel(unit); ax.grid(axis="y",alpha=0.3)
fig.suptitle("TRPO Model 1 — Phase comparison (Table VII metrics)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(RESULTS_ROOT/"boxplots_tabla7.png", dpi=150, bbox_inches="tight")
plt.show()

def plot_traces(episodes, df_eps, label, save_path):
    if not episodes: return
    median_r = df_eps["reward_total"].median()
    rep_idx  = (df_eps["reward_total"] - median_r).abs().idxmin()
    rep_ep   = episodes[rep_idx]
    steps    = np.arange(len(rep_ep["ts_reward"]))
    fig, axes = plt.subplots(1, 2, figsize=(13,4))
    axes[0].plot(steps, rep_ep["ts_cum_reward"], color="steelblue", lw=2)
    axes[0].axhline(0, color="gray", lw=0.8, ls="--")
    axes[0].fill_between(steps, rep_ep["ts_cum_reward"], alpha=0.15, color="steelblue")
    axes[0].set_title("Reward acumulado"); axes[0].set_xlabel("Paso"); axes[0].set_ylabel("€")
    axes[1].plot(steps, rep_ep["ts_action"], color="darkorange", lw=2)
    axes[1].axhline(0, color="gray", lw=0.8, ls="--")
    axes[1].set_title("Mean action (>0 charge, <0 V2G discharge)")
    axes[1].set_xlabel("Paso"); axes[1].set_ylabel("Normalizado [-1,1]")
    fig.suptitle(f"{{label}} | reward={{rep_ep['reward_total']:+.2f}} | "
                 f"profit={{rep_ep['total_profit_cost']:+.2f}}€ | "
                 f"sat={{rep_ep['user_satisfaction']:.1%}}", fontsize=11, fontweight="bold")
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches="tight"); plt.show()

plot_traces(eps_p1, df_eps_p1, "TRPO [Phase1]", RESULTS_ROOT/"traces_phase1.png")
plot_traces(eps_p2, df_eps_p2, "TRPO [Phase2]", RESULTS_ROOT/"traces_phase2.png")

fig2, ax = plt.subplots(figsize=(8,6))
ax.scatter(get_col(eps_p1,"total_profit_cost"), get_col(eps_p1,"transformer_overload_kwh"),
           label="Phase 1", alpha=0.75, s=70, color="steelblue", edgecolors="white", linewidths=0.5)
ax.scatter(get_col(eps_p2,"total_profit_cost"), get_col(eps_p2,"transformer_overload_kwh"),
           label="Phase 2", alpha=0.75, s=70, marker="^", color="darkorange", edgecolors="white", linewidths=0.5)
ax.set_xlabel("Profit (€)"); ax.set_ylabel("Overload ε_ov (kWh)")
ax.set_title("Pareto: profit vs sobrecarga", fontweight="bold")
ax.legend(); ax.grid(alpha=0.3); plt.tight_layout()
plt.savefig(RESULTS_ROOT/"pareto_profit_overload.png", dpi=150, bbox_inches="tight"); plt.show()
print("Plots saved.")
# Out:
# Plots saved.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Export results to Excel
# ─────────────────────────────────────────────────────────────────────────────
def eps_to_df(episodes, label):
    rows = [{k: v for k, v in e.items() if k in SCALAR_COLS+["episode","seed","phase"]}
            for e in episodes]
    df = pd.DataFrame(rows); df.insert(0,"algorithm",label); return df

def tabla7_row(episodes, label):
    df  = pd.DataFrame([{k: v for k, v in e.items() if k in SCALAR_COLS} for e in episodes])
    row = {"Algorithm": label}
    for col in SCALAR_COLS:
        if col in df.columns:
            row[f"{col}_mean"] = round(df[col].mean(), 6)
            row[f"{col}_std"]  = round(df[col].std(ddof=1) if len(df)>1 else 0.0, 6)
    return row

# TRPO results from EV2Gym paper Table VII (Orfanoudakis et al., 2025).
# These are default SB3 results WITHOUT HPO — our notebook adds systematic HPO on top.
# The improvement over these values is the contribution of our benchmarking framework.
paper_ref = {
    "Algorithm": "Paper_TRPO_ref (EV2Gym Table VII — no HPO)",
    "note": "TRPO evaluated in EV2Gym Table VII without HPO. Our framework adds two-phase Optuna HPO.",
    "reward_total_mean": -700.0,
    "reward_total_std": 1300.0,
    "total_profit_cost_mean": 13.5,
    "total_profit_cost_std": 8.5,
    "user_satisfaction_mean": 0.57,
    "user_satisfaction_std": 0.1,
    "energy_charged_kwh_mean": 41.0,
    "energy_charged_kwh_std": 17.0,
    "energy_discharged_kwh_mean": 88.0,
    "energy_discharged_kwh_std": 30.0,
    "transformer_overload_kwh_mean": 7.0,
    "transformer_overload_kwh_std": 13.0,
    "battery_degradation_mean": 0.00052,
    "battery_degradation_std": 0.00012,
    "exec_time_s_mean": 0.13,
    "exec_time_s_std": 0.01,
}

df_eps_all = pd.concat([eps_to_df(eps_p1,"TRPO_Phase1"), eps_to_df(eps_p2,"TRPO_Phase2")], ignore_index=True)
df_tabla7  = pd.DataFrame([tabla7_row(eps_p1,"TRPO_Phase1"), tabla7_row(eps_p2,"TRPO_Phase2"), paper_ref])
df_regime  = pd.concat([df_eps_p1, df_eps_p2], ignore_index=True)

df_opt = pd.DataFrame([
    {"phase":"Phase1","best_value":study1.best_value,"n_trials":PHASE1_N_TRIALS,
     "timesteps_trial":PHASE1_TIMESTEPS,"total_timesteps":TOTAL_TIMESTEPS,"n_envs":N_ENVS,"yaml_tuned":False},
    {"phase":"Phase2","best_value":study2.best_value,"n_trials":PHASE2_N_TRIALS,
     "timesteps_trial":PHASE2_TIMESTEPS,"total_timesteps":TOTAL_TIMESTEPS,"n_envs":N_ENVS,"yaml_tuned":True},
])

df_hps = pd.DataFrame([
    {"phase":"Phase1","optuna_value":study1.best_value,"total_timesteps":TOTAL_TIMESTEPS,
     "n_envs":N_ENVS, **best_hp_p1},
    {"phase":"Phase2","optuna_value":study2.best_value,"total_timesteps":TOTAL_TIMESTEPS,
     "n_envs":N_ENVS, **best_hp_p2},
])

# ── Convergence curves ───────────────────────────────────────────────────────
df_conv_p1 = pd.read_csv(RESULTS_ROOT / "optuna_phase1_convergence.csv")
df_conv_p2 = pd.read_csv(RESULTS_ROOT / "optuna_phase2_convergence.csv")
df_convergence = pd.concat([df_conv_p1, df_conv_p2], ignore_index=True)

# ── Update and save REPRO_LOG ─────────────────────────────────────────────────
REPRO_LOG.update({
    "phase1_optuna_best_value": float(study1.best_value),
    "phase2_optuna_best_value": float(study2.best_value),
    "phase1_best_trial": int(study1.best_trial.number),
    "phase2_best_trial": int(study2.best_trial.number),
    "phase1_total_eval_episodes": len(eps_p1),
    "phase2_total_eval_episodes": len(eps_p2),
    "phase1_yaml": str(PHASE1_BEST_YAML),
    "phase2_yaml": str(PHASE2_BEST_YAML),
    "phase2_yaml_params": {
        "spawn_multiplier"      : best_cfg_p2.get("spawn_multiplier"),
        "discharge_price_factor": best_cfg_p2.get("discharge_price_factor"),
        "transformer_max_power" : best_cfg_p2.get("transformer", {}).get("max_power"),
    },
    "phase1_best_hps": best_hp_p1,
    "phase2_best_hps": best_hp_p2,
})
with open(RESULTS_ROOT / "reproducibility_log.json", "w") as f:
    json.dump(REPRO_LOG, f, indent=2)
print("Reproducibility log saved.")

out = RESULTS_ROOT / "trpo_model1_report.xlsx"
with pd.ExcelWriter(out) as w:
    df_eps_all.to_excel(   w, sheet_name="episodes_all",       index=False)
    df_tabla7.to_excel(    w, sheet_name="tabla7_vs_paper",    index=False)
    df_all_sum.to_excel(   w, sheet_name="summary_full",       index=False)
    df_regime.to_excel(    w, sheet_name="regime_analysis",    index=False)
    df_opt.to_excel(       w, sheet_name="optuna_comparison",  index=False)
    df_hps.to_excel(       w, sheet_name="best_hyperparams",   index=False)
    df_convergence.to_excel(w, sheet_name="optuna_convergence", index=False)

print(f"Excel report: {out}")
df_eps_all.to_csv(    RESULTS_ROOT / "episodes_all.csv",             index=False)
df_tabla7.to_csv(     RESULTS_ROOT / "tabla7_vs_paper.csv",          index=False)
df_convergence.to_csv(RESULTS_ROOT / "optuna_convergence_both.csv",  index=False)
print("CSVs saved.")
# Out:
# Reproducibility log saved.
# Excel report: results_trpo_model1/trpo_model1_report.xlsx
# CSVs saved.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Final summary
# ─────────────────────────────────────────────────────────────────────────────
def arr(eps, col): return np.array([e[col] for e in eps])
def fmt(a, mult=1):
    return f"{a.mean()*mult:+.2f} ± {a.std(ddof=1)*mult:.2f}" if len(a)>1 else f"{a.mean()*mult:+.2f} (n=1)"

r1  = arr(eps_p1,"reward_total");             r2  = arr(eps_p2,"reward_total")
pr1 = arr(eps_p1,"total_profit_cost");        pr2 = arr(eps_p2,"total_profit_cost")
s1  = arr(eps_p1,"user_satisfaction");        s2  = arr(eps_p2,"user_satisfaction")
ov1 = arr(eps_p1,"transformer_overload_kwh"); ov2 = arr(eps_p2,"transformer_overload_kwh")
q1  = arr(eps_p1,"battery_degradation");      q2  = arr(eps_p2,"battery_degradation")

sep = "="*75
print(sep)
print(f"  TRPO Model 1 — FINAL SUMMARY")
print(f"  Steps: {TOTAL_TIMESTEPS:,} | Envs: {N_ENVS} | Eps: {len(eps_p1)}/fase")
print(sep)
print(f"  {'Metric':<28} {'Phase 1 (HPs)':>22}   {'Phase 2 (HPs+YAML)':>22}   {'Paper ref':>15}")
print(f"  {'-'*78}")
for lbl, a1, a2, paper, mult in [
    ("Reward",          r1,  r2,  "—",   1),
    ("Profit (€)",      pr1, pr2, "13.5±8.5",   1),
    ("User sat. (%)",   s1,  s2,  "57±10",      100),
    ("Overload (kWh)",  ov1, ov2, "7±13",  1),
    ("Q_lost (×10⁻³)", q1,  q2,  "0.52±0.12",    1e3),
]:
    print(f"  {lbl:<28} {fmt(a1,mult):>22}   {fmt(a2,mult):>22}   {paper:>15}")

# ── Battery degradation monetization  ────────
# Translates Q_lost (fraction of battery capacity) to €/episode.
# Assumption: Li-ion pack replacement €150/kWh (conservative 2024 estimate);
#             70 kWh per EV battery (from YAML ev.battery_capacity).
# Effective profit = reported profit − degradation_cost.
LI_ION_EUR_PER_KWH = 150.0
BAT_CAP_KWH        = 70.0
print(sep)
print("  BATTERY DEGRADATION COST ESTIMATE :")
print(f"  Li-ion replacement: €{LI_ION_EUR_PER_KWH:.0f}/kWh × {BAT_CAP_KWH:.0f} kWh/battery")
for _phase, _q in [("Phase1", q1), ("Phase2", q2)]:
    _degrad_eur = _q * BAT_CAP_KWH * LI_ION_EUR_PER_KWH
    print(f"  [{_phase}] Q_lost={_q.mean()*1e3:.3f}±{_q.std(ddof=1)*1e3:.3f}×10⁻³"
          f"  →  degrad_cost≈{_degrad_eur.mean():.2f}±{_degrad_eur.std(ddof=1):.2f} €/ep")
print("  NOTE: degradation cost is not part of the reward — net profit = reported profit − degrad_cost")

print(sep)
for ph, df_e in [("Phase 1", df_eps_p1), ("Phase 2", df_eps_p2)]:
    print(f"  [{ph}] congested={df_e['congested'].sum()}/{len(df_e)} | "
          f"sat>=80%={df_e['high_sat'].sum()}/{len(df_e)} | "
          f"profitable={df_e['profitable'].sum()}/{len(df_e)}")
print(sep)

# ── Statistical caution ───────────────────────────────────────────────────────
print("\nSTATISTICAL NOTE:")
for label, arr_data, nm in [("Phase1", pr1, "Profit"), ("Phase2", pr2, "Profit"),
                              ("Phase1", s1,  "Sat"),    ("Phase2", s2,  "Sat")]:
    if len(arr_data) > 1:
        mn, sd = arr_data.mean(), arr_data.std(ddof=1)
        flag = " ← std > mean — treat ranking as directional only" \
               if abs(sd) > abs(mn) and mn != 0 else ""
        print(f"  TRPO [{label}] {nm}: {mn:+.2f} ± {sd:.2f}{flag}")
print(sep)
# Out:
# ===========================================================================
#   TRPO Model 1 — FINAL SUMMARY
#   Steps: 1,000,000 | Envs: 30 | Eps: 100/fase
# ===========================================================================
#   Metric                                Phase 1 (HPs)       Phase 2 (HPs+YAML)         Paper ref
#   ------------------------------------------------------------------------------
#   Reward                                +9.82 ± 16.85           +16.99 ± 39.85                 —
#   Profit (€)                           +36.26 ± 35.51           +54.46 ± 49.91          13.5±8.5
#   User sat. (%)                        +37.97 ± 14.22           +31.96 ± 11.80             57±10
#   Overload (kWh)                         +0.00 ± 0.00             +0.00 ± 0.00              7±13
#   Q_lost (×10⁻³)                         +0.27 ± 0.12             +0.45 ± 0.20         0.52±0.12
# ===========================================================================
#   BATTERY DEGRADATION COST ESTIMATE :
#   Li-ion replacement: €150/kWh × 70 kWh/battery
#   [Phase1] Q_lost=0.273±0.123×10⁻³  →  degrad_cost≈2.87±1.29 €/ep
#   [Phase2] Q_lost=0.453±0.198×10⁻³  →  degrad_cost≈4.76±2.08 €/ep
#   NOTE: degradation cost is not part of the reward — net profit = reported profit − degrad_cost
# ===========================================================================
#   [Phase 1] congested=0/100 | sat>=80%=0/100 | profitable=100/100
#   [Phase 2] congested=0/100 | sat>=80%=0/100 | profitable=98/100
# ===========================================================================
#
# STATISTICAL NOTE:
#   TRPO [Phase1] Profit: +36.26 ± 35.51
#   TRPO [Phase2] Profit: +54.46 ± 49.91
#   TRPO [Phase1] Sat: +0.38 ± 0.14
#   TRPO [Phase2] Sat: +0.32 ± 0.12
# ===========================================================================

# %%
# ─────────────────────────────────────────────────────────────────────────────
#   Bootstrap CIs + Wilcoxon signed-rank tests
#  Ref: Agarwal et al. NeurIPS 2021 'Deep RL at the Statistical Precipice'
#
#  TEST      → N_BOOTSTRAP = 100    (seconds)
#  PRODUCTION  → N_BOOTSTRAP = 10_000  (minutes — publishable results)
# ─────────────────────────────────────────────────────────────────────────────

from scipy import stats as scipy_stats

N_BOOTSTRAP = 100          # TEST → production: 10_000

def bootstrap_ci(data, stat_fn=np.mean, n=N_BOOTSTRAP, ci=0.95):
    rng  = np.random.default_rng(42)
    boot = [stat_fn(rng.choice(data, size=len(data), replace=True)) for _ in range(n)]
    alpha = (1 - ci) / 2
    return np.percentile(boot, [alpha*100, (1-alpha)*100])

def wilcoxon_test(a, b):
    n = min(len(a), len(b))
    try:
        stat, p = scipy_stats.wilcoxon(a[:n], b[:n])
        return {'stat': float(stat), 'p_value': float(p),
                'significant_at_05': bool(p < 0.05)}
    except Exception as e:
        return {'stat': None, 'p_value': None, 'error': str(e)}

print(f'Bootstrap CIs (N={N_BOOTSTRAP}) + Wilcoxon tests')
print('='*65)

metrics_ci = [
    ('total_profit_cost',        'Profit (euro)',      1),
    ('user_satisfaction',        'User sat. (%)',      100),
    ('transformer_overload_kwh', 'Overload (kWh)',     1),
    ('battery_degradation',      'Q_lost (x10^-3)',    1e3),
]

ci_results = {}
for col, lbl, mult in metrics_ci:
    a1 = np.array([e[col]*mult for e in eps_p1])
    a2 = np.array([e[col]*mult for e in eps_p2])
    lo1, hi1 = bootstrap_ci(a1)
    lo2, hi2 = bootstrap_ci(a2)
    wtest    = wilcoxon_test(
        np.array([e[col] for e in eps_p1]),
        np.array([e[col] for e in eps_p2]))
    ci_results[col] = {
        'phase1_mean': float(a1.mean()), 'phase1_ci95': [float(lo1), float(hi1)],
        'phase2_mean': float(a2.mean()), 'phase2_ci95': [float(lo2), float(hi2)],
        'wilcoxon_p1_vs_p2': wtest,
    }
    sig = '* p<0.05' if wtest.get('significant_at_05') else 'ns'
    print(f'\n  {lbl}')
    print(f'    F1: {a1.mean():+.3f}  95% CI [{lo1:+.3f}, {hi1:+.3f}]')
    print(f'    F2: {a2.mean():+.3f}  95% CI [{lo2:+.3f}, {hi2:+.3f}]')
    pval = wtest.get('p_value')
    pstr = f'{pval:.4f}' if pval is not None else 'N/A'
    print(f'    Wilcoxon F1 vs F2: p={pstr}  {sig}')

with open(RESULTS_ROOT / 'bootstrap_ci_results.json', 'w') as f:
    json.dump(ci_results, f, indent=2)
print(f'\nSaved: bootstrap_ci_results.json  (N_BOOTSTRAP={N_BOOTSTRAP})')
print('For production: cambiar N_BOOTSTRAP = 10_000')
# Out:
# Bootstrap CIs (N=100) + Wilcoxon tests
# =================================================================
#
#   Profit (euro)
#     F1: +36.260  95% CI [+29.957, +43.523]
#     F2: +54.459  95% CI [+44.947, +65.037]
#     Wilcoxon F1 vs F2: p=0.0000  * p<0.05
#
#   User sat. (%)
#     F1: +37.974  95% CI [+35.426, +40.652]
#     F2: +31.964  95% CI [+29.935, +33.920]
#     Wilcoxon F1 vs F2: p=0.0000  * p<0.05
#
#   Overload (kWh)
#     F1: +0.000  95% CI [+0.000, +0.000]
#     F2: +0.000  95% CI [+0.000, +0.000]
#     Wilcoxon F1 vs F2: p=N/A  ns
#
#   Q_lost (x10^-3)
#     F1: +0.273  95% CI [+0.248, +0.294]
#     F2: +0.453  95% CI [+0.421, +0.491]
#     Wilcoxon F1 vs F2: p=0.0000  * p<0.05
#
# Saved: bootstrap_ci_results.json  (N_BOOTSTRAP=100)
# For production: cambiar N_BOOTSTRAP = 10_000

# %%
# ─────────────────────────────────────────────────────────────────────────────
#   Sensitivity: HPO budget (n_trials)
#  ¿30 trials es suficiente? Corremos estudios con distintos budgets y
#  comparamos la curva best-so-far para verificar convergencia.
#  Ref: Hertel et al.; 
#
#  Valores TEST/PROD vienen de la celda MODE (celda 1).
#  TEST:  SENSITIVITY_TRIALS=[3,5],   SENSITIVITY_STEPS=2_000    → minutos
#  PROD:  SENSITIVITY_TRIALS=[30,60,100], SENSITIVITY_STEPS=100_000 → horas
# ─────────────────────────────────────────────────────────────────────────────

SENSITIVITY_SEED = 42
# SENSITIVITY_TRIALS y SENSITIVITY_STEPS vienen de celda MODE

def run_sensitivity_study(n_trials, study_id=0):
    set_seed(SENSITIVITY_SEED)
    study = optuna.create_study(
        direction='maximize',
        sampler=optuna.samplers.TPESampler(seed=SENSITIVITY_SEED),
        study_name=f'trpo_sensitivity_{study_id}_{n_trials}t'
    )
    def obj(trial):
        arch = sample_arch(trial)
        hp   = sample_algo_hparams(trial)
        yp   = save_cfg(BASE_CFG,
            RESULTS_ROOT / f'sens_{study_id}_{trial.number}.yaml')
        try:
            te = make_vec_train_env_optuna(
                str(yp), seed=SENSITIVITY_SEED, n_envs=2)
            m  = build_model(hp, arch, te,
                seed=SENSITIVITY_SEED, n_envs=2)
            m.learn(total_timesteps=SENSITIVITY_STEPS)
            vp = str(RESULTS_ROOT / f'sens_vn_{study_id}_{trial.number}.pkl')
            te.save(vp); te.close()
            score = quick_eval(m, str(yp), vp, n_eps=4)
            return score
        except Exception as e:
            print(f'  Trial {trial.number} error: {e}')
            print(f'    Trial {trial.number} error: {e}')
            return -1e9
    study.optimize(obj, n_trials=n_trials, show_progress_bar=False)
    best, curve = -float('inf'), []
    for t in sorted(study.trials, key=lambda x: x.number):
        if t.value is not None and t.value > best and t.value > -1e8:
            best = t.value
        curve.append({'trial': t.number, 'value': t.value,
                      'best_so_far': best if best > -1e8 else None,
                      'n_trials_budget': n_trials})
    n_failed = sum(1 for t in study.trials if t.value is None or t.value <= -1e8)
    print(f'  Failed trials: {n_failed}/{n_trials}')
    return curve, study.best_value

print(f'HPO budget sensitivity | trials: {SENSITIVITY_TRIALS}')
print(f'Steps per trial: {SENSITIVITY_STEPS:,}')
print('='*55)

all_curves = []
for sid, n_t in enumerate(SENSITIVITY_TRIALS):
    print(f'\nRunning {n_t} trials...')
    t0 = time.time()
    curve, best_val = run_sensitivity_study(n_t, study_id=sid)
    all_curves.extend(curve)
    elapsed = (time.time()-t0)/60
    if best_val <= -1e8:
        print(f'  ⚠ ALL TRIALS FAILED — check errors above')
    else:
        print(f'  Best: {best_val:.3f} | Time: {elapsed:.1f} min')

df_sens = pd.DataFrame(all_curves)
df_sens.to_csv(RESULTS_ROOT / 'sensitivity_hpo_budget.csv', index=False)

# Only plot if there were successful trials
df_ok = df_sens[df_sens['best_so_far'].notna()]
if len(df_ok) > 0:
    fig, ax = plt.subplots(figsize=(9, 5))
    for sid, n_t in enumerate(SENSITIVITY_TRIALS):
        sub = df_ok[df_ok['n_trials_budget'] == n_t]
        if len(sub) == 0: continue
        bsf = sub['best_so_far'].iloc[-1]
        ax.plot(sub['trial'], sub['best_so_far'], marker='o', ms=4,
                label=f'{n_t} trials (best={bsf:.2f})')
    ax.set_xlabel('Trial #'); ax.set_ylabel('Best score so far')
    ax.set_title('Sensitivity: HPO budget'); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(RESULTS_ROOT / 'sensitivity_hpo_budget.png', dpi=150)
    plt.show()
    print('Saved: sensitivity_hpo_budget.csv + .png')
else:
    print('Sin successful trials — check configuration del entorno')
# Out:
# HPO budget sensitivity | trials: [30, 60, 100]
# Steps per trial: 100,000
# =======================================================
#
# Running 30 trials...
#   Failed trials: 0/30
#   Best: 26.084 | Time: 383.1 min
#
# Running 60 trials...
#   Failed trials: 0/60
#   Best: 31.456 | Time: 759.0 min
#
# Running 100 trials...
#   Failed trials: 0/100
#   Best: 32.499 | Time: 1224.2 min
# Saved: sensitivity_hpo_budget.csv + .png

# %%
# ─────────────────────────────────────────────────────────────────────────────
#  Ablation: proxy reward (Model-2) vs direct (Model-1)
#
#  Entrena UNA run adicional con el reward real (sparse, Model-1)
#  y compara contra el agente proxy ya entrenado arriba.
#  Usa los best HPs de F1 para aislar el efecto del reward.
#
#  Valores TEST/PROD vienen de la celda MODE (celda 1).
#  TEST: ABLATION_TIMESTEPS=5_000  → expected result: small difference
#        (with few steps both models barely learn — expected in TEST mode)
#  PROD: ABLATION_TIMESTEPS=1_000_000 → diferencia real y significativa
#
#  NOTA: In TEST mode near-identical results are expected — insufficient steps for divergence.
#  The proxy vs. direct difference only appears clearly with full training (1M steps).
# ─────────────────────────────────────────────────────────────────────────────

from ev2gym.rl_agent.reward import profit_maximization as model1_reward

# ABLATION_TIMESTEPS y ABLATION_N_ENVS vienen de celda MODE

def make_vec_direct_env(config_file, seed=42, n_envs=4):
    'Training environment with direct Model-1 reward (sparse, no proxy).'
    def _make():
        import gymnasium as gym
        return gym.make('EV2Gym-v1',
                        config_file=config_file,
                        reward_function=model1_reward,
                        state_function=V2G_profit_max)
    venv = SubprocVecEnv([_make]*n_envs) if n_envs > 1 else DummyVecEnv([_make])
    return VecNormalize(venv, norm_obs=True, norm_reward=True,
                        clip_obs=10.0, clip_reward=10.0)

print('Proxy reward ablation: Model-2 (proxy) vs Model-1 (direct)')
print(f'Timesteps: {ABLATION_TIMESTEPS:,} | Envs: {ABLATION_N_ENVS}')
print(f'Note: con TEST ({ABLATION_TIMESTEPS:,} steps) results will be')
print(f'      near-identical — the real difference only appears in PROD (1M steps).')
print('='*55)

set_seed(42)
te_direct = make_vec_direct_env(
    str(PHASE1_BEST_YAML), seed=42, n_envs=ABLATION_N_ENVS)
m_direct  = build_model(best_hp_p1, best_arch_p1, te_direct,
                         seed=42, n_envs=ABLATION_N_ENVS)
print('Training with direct Model-1 reward...')
t0 = time.time()
m_direct.learn(total_timesteps=ABLATION_TIMESTEPS, progress_bar=True)
print(f'Completed in {(time.time()-t0)/60:.1f} min')
vn_abl = str(RESULTS_ROOT / 'vecnorm_ablation_direct.pkl')
m_direct.save(str(RESULTS_ROOT / 'model_ablation_direct'))
te_direct.save(vn_abl)
te_direct.close()

print('\nEvaluating ambos...')
eps_proxy  = evaluate_model(model_p1, PHASE1_BEST_YAML, vn_path_p1, 'Proxy_M2')
eps_direct = evaluate_model(m_direct, PHASE1_BEST_YAML, vn_abl,      'Direct_M1')

print('\nABLATION RESULTS:')
for lbl, eps in [('Proxy (Model-2)', eps_proxy), ('Direct (Model-1)', eps_direct)]:
    pr  = np.array([e['total_profit_cost']       for e in eps])
    sat = np.array([e['user_satisfaction']        for e in eps])
    ov  = np.array([e['transformer_overload_kwh'] for e in eps])
    print(f'  {lbl:<22} profit={pr.mean():+.2f}+/-{pr.std():.2f}  '
          f'sat={sat.mean():.1%}  ov={ov.mean():.1f} kWh')

if ABLATION_TIMESTEPS < 100_000:
    print()
    print('TEST NOTE: With few steps both models barely learn.')
    print('Near-identical results are expected in TEST mode.')
    print("Set MODE='PROD' to observe the true difference (1M steps).")

df_abl = pd.concat([
    pd.DataFrame([{k:v for k,v in e.items()
                   if k in SCALAR_COLS+['episode','seed','phase']}
                  for e in eps_proxy]),
    pd.DataFrame([{k:v for k,v in e.items()
                   if k in SCALAR_COLS+['episode','seed','phase']}
                  for e in eps_direct]),
], ignore_index=True)
df_abl.to_csv(RESULTS_ROOT / 'ablation_proxy_vs_direct.csv', index=False)
print('\nSaved: ablation_proxy_vs_direct.csv')
# Out:
# Proxy reward ablation: Model-2 (proxy) vs Model-1 (direct)
# Timesteps: 1,000,000 | Envs: 4
# Note: con TEST (1,000,000 steps) results will be
#       near-identical — the real difference only appears in PROD (1M steps).
# =======================================================
# Training with direct Model-1 reward...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Completed in 58.2 min
#
# Evaluating ambos...
#   [Proxy_M2] Ep  1 | reward=+11.92 | profit=+19.87€ | sat=40.4% | overload=0.00kWh | Qlost=0.00020 | EVs=4
#   [Proxy_M2] Ep  2 | reward=+4.30 | profit=+9.48€ | sat=46.1% | overload=0.00kWh | Qlost=0.00013 | EVs=4
#   [Proxy_M2] Ep  3 | reward=+3.82 | profit=+39.01€ | sat=21.4% | overload=0.00kWh | Qlost=0.00022 | EVs=3
#   [Proxy_M2] Ep  4 | reward=+49.47 | profit=+108.13€ | sat=21.4% | overload=0.00kWh | Qlost=0.00042 | EVs=5
#   [Proxy_M2] Ep  5 | reward=+66.17 | profit=+148.29€ | sat=21.4% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Proxy_M2] Ep  6 | reward=+29.02 | profit=+87.68€ | sat=21.4% | overload=0.00kWh | Qlost=0.00042 | EVs=5
#   [Proxy_M2] Ep  7 | reward=+41.24 | profit=+88.17€ | sat=21.4% | overload=0.00kWh | Qlost=0.00030 | EVs=4
#   [Proxy_M2] Ep  8 | reward=+12.55 | profit=+15.70€ | sat=55.1% | overload=0.00kWh | Qlost=0.00016 | EVs=3
#   [Proxy_M2] Ep  9 | reward=+4.02 | profit=+14.44€ | sat=45.0% | overload=0.00kWh | Qlost=0.00023 | EVs=6
#   [Proxy_M2] Ep 10 | reward=+9.55 | profit=+17.35€ | sat=44.4% | overload=0.00kWh | Qlost=0.00020 | EVs=5
#   [Proxy_M2] Ep 11 | reward=+3.00 | profit=+4.47€ | sat=50.8% | overload=0.00kWh | Qlost=0.00007 | EVs=2
#   [Proxy_M2] Ep 12 | reward=+1.67 | profit=+6.26€ | sat=53.8% | overload=0.00kWh | Qlost=0.00017 | EVs=5
#   [Proxy_M2] Ep 13 | reward=+13.53 | profit=+77.03€ | sat=25.3% | overload=0.00kWh | Qlost=0.00049 | EVs=7
#   [Proxy_M2] Ep 14 | reward=-0.28 | profit=+9.16€ | sat=47.0% | overload=0.00kWh | Qlost=0.00018 | EVs=4
#   [Proxy_M2] Ep 15 | reward=+16.96 | profit=+21.14€ | sat=49.5% | overload=0.00kWh | Qlost=0.00022 | EVs=5
#   [Proxy_M2] Ep 16 | reward=+4.79 | profit=+16.87€ | sat=45.2% | overload=0.00kWh | Qlost=0.00027 | EVs=6
#   [Proxy_M2] Ep 17 | reward=+1.29 | profit=+2.89€ | sat=56.3% | overload=0.00kWh | Qlost=0.00014 | EVs=4
#   [Proxy_M2] Ep 18 | reward=+5.78 | profit=+63.30€ | sat=26.3% | overload=0.00kWh | Qlost=0.00039 | EVs=6
#   [Proxy_M2] Ep 19 | reward=+13.45 | profit=+50.25€ | sat=31.5% | overload=0.00kWh | Qlost=0.00037 | EVs=6
#   [Proxy_M2] Ep 20 | reward=+4.20 | profit=+6.20€ | sat=51.8% | overload=0.00kWh | Qlost=0.00014 | EVs=3
#   [Proxy_M2] Ep 21 | reward=+16.86 | profit=+41.17€ | sat=36.1% | overload=0.00kWh | Qlost=0.00035 | EVs=6
#   [Proxy_M2] Ep 22 | reward=+2.91 | profit=+19.75€ | sat=35.1% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Proxy_M2] Ep 23 | reward=-2.06 | profit=+9.67€ | sat=21.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Proxy_M2] Ep 24 | reward=+0.59 | profit=+35.08€ | sat=26.4% | overload=0.00kWh | Qlost=0.00026 | EVs=4
#   [Proxy_M2] Ep 25 | reward=+11.37 | profit=+18.41€ | sat=52.7% | overload=0.00kWh | Qlost=0.00029 | EVs=7
#   [Proxy_M2] Ep 26 | reward=+17.29 | profit=+51.52€ | sat=34.0% | overload=0.00kWh | Qlost=0.00043 | EVs=7
#   [Proxy_M2] Ep 27 | reward=+1.19 | profit=+2.10€ | sat=65.5% | overload=0.00kWh | Qlost=0.00011 | EVs=4
#   [Proxy_M2] Ep 28 | reward=+21.48 | profit=+101.27€ | sat=21.7% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Proxy_M2] Ep 29 | reward=-0.73 | profit=+42.79€ | sat=35.6% | overload=0.00kWh | Qlost=0.00047 | EVs=8
#   [Proxy_M2] Ep 30 | reward=-7.01 | profit=+4.72€ | sat=21.4% | overload=0.00kWh | Qlost=0.00004 | EVs=1
#   [Proxy_M2] Ep 31 | reward=+3.48 | profit=+28.18€ | sat=32.6% | overload=0.00kWh | Qlost=0.00027 | EVs=5
#   [Proxy_M2] Ep 32 | reward=+11.86 | profit=+26.01€ | sat=41.6% | overload=0.00kWh | Qlost=0.00024 | EVs=5
#   [Proxy_M2] Ep 33 | reward=-17.10 | profit=+23.72€ | sat=23.3% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Proxy_M2] Ep 34 | reward=+7.67 | profit=+48.93€ | sat=33.9% | overload=0.00kWh | Qlost=0.00042 | EVs=8
#   [Proxy_M2] Ep 35 | reward=+47.56 | profit=+106.22€ | sat=21.4% | overload=0.00kWh | Qlost=0.00037 | EVs=5
#   [Proxy_M2] Ep 36 | reward=+7.46 | profit=+24.11€ | sat=42.4% | overload=0.00kWh | Qlost=0.00026 | EVs=7
#   [Proxy_M2] Ep 37 | reward=+1.11 | profit=+24.82€ | sat=34.3% | overload=0.00kWh | Qlost=0.00020 | EVs=3
#   [Proxy_M2] Ep 38 | reward=+4.53 | profit=+7.15€ | sat=61.3% | overload=0.00kWh | Qlost=0.00019 | EVs=6
#   [Proxy_M2] Ep 39 | reward=+2.32 | profit=+37.19€ | sat=27.7% | overload=0.00kWh | Qlost=0.00032 | EVs=5
#   [Proxy_M2] Ep 40 | reward=+8.87 | profit=+43.35€ | sat=31.6% | overload=0.00kWh | Qlost=0.00035 | EVs=6
#   [Proxy_M2] Ep 41 | reward=+5.68 | profit=+13.07€ | sat=48.4% | overload=0.00kWh | Qlost=0.00027 | EVs=6
#   [Proxy_M2] Ep 42 | reward=+54.69 | profit=+136.08€ | sat=21.5% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Proxy_M2] Ep 43 | reward=+4.79 | profit=+6.87€ | sat=53.5% | overload=0.00kWh | Qlost=0.00013 | EVs=4
#   [Proxy_M2] Ep 44 | reward=+0.78 | profit=+17.93€ | sat=40.0% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Proxy_M2] Ep 45 | reward=-0.59 | profit=+5.99€ | sat=42.9% | overload=0.00kWh | Qlost=0.00011 | EVs=3
#   [Proxy_M2] Ep 46 | reward=+7.24 | profit=+13.44€ | sat=51.6% | overload=0.00kWh | Qlost=0.00033 | EVs=7
#   [Proxy_M2] Ep 47 | reward=+7.28 | profit=+31.40€ | sat=50.4% | overload=0.00kWh | Qlost=0.00025 | EVs=5
#   [Proxy_M2] Ep 48 | reward=+3.93 | profit=+6.57€ | sat=58.7% | overload=0.00kWh | Qlost=0.00024 | EVs=8
#   [Proxy_M2] Ep 49 | reward=+6.68 | profit=+9.44€ | sat=67.7% | overload=0.00kWh | Qlost=0.00024 | EVs=6
#   [Proxy_M2] Ep 50 | reward=+7.62 | profit=+11.46€ | sat=57.3% | overload=0.00kWh | Qlost=0.00030 | EVs=7
#   [Proxy_M2] Ep 51 | reward=+98.28 | profit=+182.07€ | sat=23.9% | overload=0.00kWh | Qlost=0.00063 | EVs=8
#   [Proxy_M2] Ep 52 | reward=+21.42 | profit=+68.34€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Proxy_M2] Ep 53 | reward=+0.38 | profit=+3.17€ | sat=61.9% | overload=0.00kWh | Qlost=0.00017 | EVs=7
#   [Proxy_M2] Ep 54 | reward=+4.19 | profit=+16.47€ | sat=50.7% | overload=0.00kWh | Qlost=0.00034 | EVs=7
#   [Proxy_M2] Ep 55 | reward=+5.99 | profit=+70.48€ | sat=25.7% | overload=0.00kWh | Qlost=0.00051 | EVs=7
#   [Proxy_M2] Ep 56 | reward=+1.63 | profit=+2.02€ | sat=76.9% | overload=0.00kWh | Qlost=0.00020 | EVs=6
#   [Proxy_M2] Ep 57 | reward=-7.66 | profit=+10.80€ | sat=35.2% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Proxy_M2] Ep 58 | reward=+15.09 | profit=+29.12€ | sat=43.0% | overload=0.00kWh | Qlost=0.00031 | EVs=7
#   [Proxy_M2] Ep 59 | reward=-8.10 | profit=+50.56€ | sat=21.4% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Proxy_M2] Ep 60 | reward=+10.32 | profit=+59.19€ | sat=25.7% | overload=0.00kWh | Qlost=0.00044 | EVs=6
#   [Proxy_M2] Ep 61 | reward=+4.73 | profit=+5.15€ | sat=79.6% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Proxy_M2] Ep 62 | reward=+4.66 | profit=+24.74€ | sat=36.2% | overload=0.00kWh | Qlost=0.00019 | EVs=3
#   [Proxy_M2] Ep 63 | reward=+9.62 | profit=+56.55€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Proxy_M2] Ep 64 | reward=+34.00 | profit=+104.39€ | sat=21.4% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Proxy_M2] Ep 65 | reward=+6.60 | profit=+12.24€ | sat=41.1% | overload=0.00kWh | Qlost=0.00015 | EVs=3
#   [Proxy_M2] Ep 66 | reward=+17.36 | profit=+23.16€ | sat=48.1% | overload=0.00kWh | Qlost=0.00026 | EVs=6
#   [Proxy_M2] Ep 67 | reward=+17.18 | profit=+45.30€ | sat=40.7% | overload=0.00kWh | Qlost=0.00045 | EVs=9
#   [Proxy_M2] Ep 68 | reward=+8.63 | profit=+27.30€ | sat=38.4% | overload=0.00kWh | Qlost=0.00028 | EVs=5
#   [Proxy_M2] Ep 69 | reward=+13.02 | profit=+20.96€ | sat=47.7% | overload=0.00kWh | Qlost=0.00028 | EVs=6
#   [Proxy_M2] Ep 70 | reward=+4.38 | profit=+21.77€ | sat=25.1% | overload=0.00kWh | Qlost=0.00015 | EVs=2
#   [Proxy_M2] Ep 71 | reward=+0.21 | profit=+1.30€ | sat=59.9% | overload=0.00kWh | Qlost=0.00010 | EVs=3
#   [Proxy_M2] Ep 72 | reward=-4.50 | profit=+30.70€ | sat=21.4% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#   [Proxy_M2] Ep 73 | reward=+22.89 | profit=+81.55€ | sat=21.4% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Proxy_M2] Ep 74 | reward=+2.41 | profit=+9.88€ | sat=43.2% | overload=0.00kWh | Qlost=0.00018 | EVs=4
#   [Proxy_M2] Ep 75 | reward=-5.41 | profit=+49.46€ | sat=22.2% | overload=0.00kWh | Qlost=0.00035 | EVs=5
#   [Proxy_M2] Ep 76 | reward=+3.05 | profit=+29.26€ | sat=39.3% | overload=0.00kWh | Qlost=0.00033 | EVs=6
#   [Proxy_M2] Ep 77 | reward=+1.13 | profit=+5.43€ | sat=53.0% | overload=0.00kWh | Qlost=0.00014 | EVs=4
#   [Proxy_M2] Ep 78 | reward=-4.78 | profit=+65.61€ | sat=21.4% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Proxy_M2] Ep 79 | reward=-4.76 | profit=+12.90€ | sat=45.3% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Proxy_M2] Ep 80 | reward=-0.23 | profit=+11.84€ | sat=39.2% | overload=0.00kWh | Qlost=0.00012 | EVs=2
#   [Proxy_M2] Ep 81 | reward=+4.20 | profit=+16.61€ | sat=39.1% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Proxy_M2] Ep 82 | reward=+7.53 | profit=+9.69€ | sat=56.8% | overload=0.00kWh | Qlost=0.00016 | EVs=4
#   [Proxy_M2] Ep 83 | reward=+36.83 | profit=+83.76€ | sat=21.4% | overload=0.00kWh | Qlost=0.00033 | EVs=4
#   [Proxy_M2] Ep 84 | reward=+1.04 | profit=+1.35€ | sat=57.8% | overload=0.00kWh | Qlost=0.00002 | EVs=1
#   [Proxy_M2] Ep 85 | reward=+4.56 | profit=+8.35€ | sat=32.7% | overload=0.00kWh | Qlost=0.00006 | EVs=1
#   [Proxy_M2] Ep 86 | reward=+12.70 | profit=+45.78€ | sat=34.0% | overload=0.00kWh | Qlost=0.00034 | EVs=6
#   [Proxy_M2] Ep 87 | reward=+12.46 | profit=+23.36€ | sat=42.9% | overload=0.00kWh | Qlost=0.00026 | EVs=6
#   [Proxy_M2] Ep 88 | reward=+4.91 | profit=+8.99€ | sat=46.1% | overload=0.00kWh | Qlost=0.00015 | EVs=4
#   [Proxy_M2] Ep 89 | reward=+10.87 | profit=+72.62€ | sat=26.1% | overload=0.00kWh | Qlost=0.00044 | EVs=7
#   [Proxy_M2] Ep 90 | reward=+2.38 | profit=+16.18€ | sat=32.4% | overload=0.00kWh | Qlost=0.00023 | EVs=3
#   [Proxy_M2] Ep 91 | reward=+3.43 | profit=+61.47€ | sat=26.1% | overload=0.00kWh | Qlost=0.00045 | EVs=6
#   [Proxy_M2] Ep 92 | reward=+4.77 | profit=+26.40€ | sat=35.9% | overload=0.00kWh | Qlost=0.00024 | EVs=4
#   [Proxy_M2] Ep 93 | reward=-14.02 | profit=+42.11€ | sat=24.9% | overload=0.00kWh | Qlost=0.00032 | EVs=6
#   [Proxy_M2] Ep 94 | reward=+62.26 | profit=+132.66€ | sat=21.4% | overload=0.00kWh | Qlost=0.00050 | EVs=6
#   [Proxy_M2] Ep 95 | reward=-3.76 | profit=+27.15€ | sat=29.0% | overload=0.00kWh | Qlost=0.00023 | EVs=4
#   [Proxy_M2] Ep 96 | reward=-2.18 | profit=+16.49€ | sat=41.6% | overload=0.00kWh | Qlost=0.00023 | EVs=5
#   [Proxy_M2] Ep 97 | reward=+6.76 | profit=+30.22€ | sat=21.4% | overload=0.00kWh | Qlost=0.00014 | EVs=2
#   [Proxy_M2] Ep 98 | reward=+13.50 | profit=+60.43€ | sat=21.4% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Proxy_M2] Ep 99 | reward=+6.24 | profit=+20.08€ | sat=45.4% | overload=0.00kWh | Qlost=0.00025 | EVs=7
#   [Proxy_M2] Ep 100 | reward=+1.25 | profit=+36.45€ | sat=21.4% | overload=0.00kWh | Qlost=0.00023 | EVs=3
#   [Direct_M1] Ep  1 | reward=+10.19 | profit=+19.18€ | sat=41.0% | overload=0.00kWh | Qlost=0.00027 | EVs=4
#   [Direct_M1] Ep  2 | reward=+4.21 | profit=+6.66€ | sat=52.4% | overload=0.00kWh | Qlost=0.00020 | EVs=4
#   [Direct_M1] Ep  3 | reward=+12.35 | profit=+47.55€ | sat=21.4% | overload=0.00kWh | Qlost=0.00030 | EVs=3
#   [Direct_M1] Ep  4 | reward=+48.95 | profit=+107.61€ | sat=21.4% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Direct_M1] Ep  5 | reward=+72.44 | profit=+154.56€ | sat=21.4% | overload=0.00kWh | Qlost=0.00051 | EVs=7
#   [Direct_M1] Ep  6 | reward=+45.01 | profit=+94.42€ | sat=24.5% | overload=0.00kWh | Qlost=0.00042 | EVs=5
#   [Direct_M1] Ep  7 | reward=+42.75 | profit=+89.68€ | sat=21.4% | overload=0.00kWh | Qlost=0.00030 | EVs=4
#   [Direct_M1] Ep  8 | reward=+14.10 | profit=+19.79€ | sat=68.5% | overload=0.00kWh | Qlost=0.00033 | EVs=3
#   [Direct_M1] Ep  9 | reward=+5.01 | profit=+9.26€ | sat=59.6% | overload=0.00kWh | Qlost=0.00034 | EVs=6
#   [Direct_M1] Ep 10 | reward=+4.21 | profit=+18.86€ | sat=40.1% | overload=0.00kWh | Qlost=0.00037 | EVs=5
#   [Direct_M1] Ep 11 | reward=+2.34 | profit=+2.75€ | sat=62.3% | overload=0.00kWh | Qlost=0.00006 | EVs=2
#   [Direct_M1] Ep 12 | reward=+1.08 | profit=+3.17€ | sat=66.7% | overload=0.00kWh | Qlost=0.00031 | EVs=5
#   [Direct_M1] Ep 13 | reward=+30.49 | profit=+61.51€ | sat=42.8% | overload=0.00kWh | Qlost=0.00057 | EVs=7
#   [Direct_M1] Ep 14 | reward=+0.52 | profit=+9.34€ | sat=45.7% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Direct_M1] Ep 15 | reward=+3.83 | profit=+21.69€ | sat=48.5% | overload=0.00kWh | Qlost=0.00032 | EVs=5
#   [Direct_M1] Ep 16 | reward=+5.47 | profit=+11.49€ | sat=56.0% | overload=0.00kWh | Qlost=0.00027 | EVs=6
#   [Direct_M1] Ep 17 | reward=+1.16 | profit=+2.14€ | sat=62.2% | overload=0.00kWh | Qlost=0.00021 | EVs=4
#   [Direct_M1] Ep 18 | reward=+33.19 | profit=+54.66€ | sat=40.5% | overload=0.00kWh | Qlost=0.00057 | EVs=6
#   [Direct_M1] Ep 19 | reward=+28.81 | profit=+48.39€ | sat=36.0% | overload=0.00kWh | Qlost=0.00043 | EVs=6
#   [Direct_M1] Ep 20 | reward=+4.30 | profit=+5.69€ | sat=53.9% | overload=0.00kWh | Qlost=0.00015 | EVs=3
#   [Direct_M1] Ep 21 | reward=+9.34 | profit=+44.41€ | sat=30.9% | overload=0.00kWh | Qlost=0.00051 | EVs=6
#   [Direct_M1] Ep 22 | reward=+7.40 | profit=+14.79€ | sat=49.5% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Direct_M1] Ep 23 | reward=-2.03 | profit=+9.70€ | sat=21.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Direct_M1] Ep 24 | reward=+14.13 | profit=+32.91€ | sat=34.5% | overload=0.00kWh | Qlost=0.00029 | EVs=4
#   [Direct_M1] Ep 25 | reward=+6.62 | profit=+19.60€ | sat=50.3% | overload=0.00kWh | Qlost=0.00056 | EVs=7
#   [Direct_M1] Ep 26 | reward=+17.25 | profit=+55.09€ | sat=41.9% | overload=0.00kWh | Qlost=0.00058 | EVs=7
#   [Direct_M1] Ep 27 | reward=+1.35 | profit=+2.52€ | sat=68.4% | overload=0.00kWh | Qlost=0.00022 | EVs=4
#   [Direct_M1] Ep 28 | reward=+39.63 | profit=+88.40€ | sat=33.5% | overload=0.00kWh | Qlost=0.00050 | EVs=7
#   [Direct_M1] Ep 29 | reward=+22.10 | profit=+41.70€ | sat=37.9% | overload=0.00kWh | Qlost=0.00062 | EVs=8
#   [Direct_M1] Ep 30 | reward=+0.43 | profit=+0.84€ | sat=54.9% | overload=0.00kWh | Qlost=0.00004 | EVs=1
#   [Direct_M1] Ep 31 | reward=+1.07 | profit=+33.96€ | sat=28.3% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Direct_M1] Ep 32 | reward=-3.96 | profit=+38.80€ | sat=25.3% | overload=0.00kWh | Qlost=0.00037 | EVs=5
#   [Direct_M1] Ep 33 | reward=+2.54 | profit=+18.55€ | sat=32.4% | overload=0.00kWh | Qlost=0.00024 | EVs=4
#   [Direct_M1] Ep 34 | reward=+6.16 | profit=+29.43€ | sat=55.3% | overload=0.00kWh | Qlost=0.00068 | EVs=8
#   [Direct_M1] Ep 35 | reward=+48.04 | profit=+106.70€ | sat=21.4% | overload=0.00kWh | Qlost=0.00038 | EVs=5
#   [Direct_M1] Ep 36 | reward=+4.37 | profit=+26.75€ | sat=41.0% | overload=0.00kWh | Qlost=0.00037 | EVs=7
#   [Direct_M1] Ep 37 | reward=+21.53 | profit=+30.92€ | sat=44.2% | overload=0.00kWh | Qlost=0.00035 | EVs=3
#   [Direct_M1] Ep 38 | reward=+2.87 | profit=+10.91€ | sat=48.9% | overload=0.00kWh | Qlost=0.00042 | EVs=6
#   [Direct_M1] Ep 39 | reward=-6.05 | profit=+38.29€ | sat=26.5% | overload=0.00kWh | Qlost=0.00036 | EVs=5
#   [Direct_M1] Ep 40 | reward=+8.02 | profit=+42.99€ | sat=31.0% | overload=0.00kWh | Qlost=0.00042 | EVs=6
#   [Direct_M1] Ep 41 | reward=+7.74 | profit=+10.33€ | sat=60.4% | overload=0.00kWh | Qlost=0.00046 | EVs=6
#   [Direct_M1] Ep 42 | reward=+73.67 | profit=+93.35€ | sat=45.4% | overload=0.00kWh | Qlost=0.00051 | EVs=7
#   [Direct_M1] Ep 43 | reward=-2.23 | profit=+11.19€ | sat=35.9% | overload=0.00kWh | Qlost=0.00027 | EVs=4
#   [Direct_M1] Ep 44 | reward=-22.68 | profit=+24.25€ | sat=21.4% | overload=0.00kWh | Qlost=0.00040 | EVs=4
#   [Direct_M1] Ep 45 | reward=-0.85 | profit=+4.53€ | sat=46.3% | overload=0.00kWh | Qlost=0.00015 | EVs=3
#   [Direct_M1] Ep 46 | reward=-7.40 | profit=+12.10€ | sat=42.2% | overload=0.00kWh | Qlost=0.00061 | EVs=7
#   [Direct_M1] Ep 47 | reward=+27.98 | profit=+44.92€ | sat=56.9% | overload=0.00kWh | Qlost=0.00045 | EVs=5
#   [Direct_M1] Ep 48 | reward=+1.29 | profit=+6.65€ | sat=58.1% | overload=0.00kWh | Qlost=0.00047 | EVs=8
#   [Direct_M1] Ep 49 | reward=+7.11 | profit=+12.88€ | sat=64.3% | overload=0.00kWh | Qlost=0.00053 | EVs=6
#   [Direct_M1] Ep 50 | reward=+3.86 | profit=+9.75€ | sat=53.7% | overload=0.00kWh | Qlost=0.00056 | EVs=7
#   [Direct_M1] Ep 51 | reward=+106.76 | profit=+193.47€ | sat=22.6% | overload=0.00kWh | Qlost=0.00068 | EVs=8
#   [Direct_M1] Ep 52 | reward=+29.76 | profit=+70.78€ | sat=23.2% | overload=0.00kWh | Qlost=0.00030 | EVs=4
#   [Direct_M1] Ep 53 | reward=+0.35 | profit=+1.98€ | sat=74.2% | overload=0.00kWh | Qlost=0.00038 | EVs=7
#   [Direct_M1] Ep 54 | reward=-4.45 | profit=-0.35€ | sat=58.6% | overload=0.00kWh | Qlost=0.00078 | EVs=7
#   [Direct_M1] Ep 55 | reward=+6.44 | profit=+72.58€ | sat=25.5% | overload=0.00kWh | Qlost=0.00054 | EVs=7
#   [Direct_M1] Ep 56 | reward=-3.50 | profit=+4.32€ | sat=55.3% | overload=0.00kWh | Qlost=0.00042 | EVs=6
#   [Direct_M1] Ep 57 | reward=-0.52 | profit=+3.37€ | sat=48.6% | overload=0.00kWh | Qlost=0.00019 | EVs=4
#   [Direct_M1] Ep 58 | reward=+14.77 | profit=+28.81€ | sat=44.4% | overload=0.00kWh | Qlost=0.00046 | EVs=7
#   [Direct_M1] Ep 59 | reward=+5.28 | profit=+47.17€ | sat=30.0% | overload=0.00kWh | Qlost=0.00041 | EVs=5
#   [Direct_M1] Ep 60 | reward=+6.36 | profit=+61.39€ | sat=25.0% | overload=0.00kWh | Qlost=0.00049 | EVs=6
#   [Direct_M1] Ep 61 | reward=+3.05 | profit=+4.38€ | sat=80.4% | overload=0.00kWh | Qlost=0.00065 | EVs=7
#   [Direct_M1] Ep 62 | reward=+11.37 | profit=+23.56€ | sat=47.8% | overload=0.00kWh | Qlost=0.00024 | EVs=3
#   [Direct_M1] Ep 63 | reward=+35.43 | profit=+82.13€ | sat=21.5% | overload=0.00kWh | Qlost=0.00048 | EVs=4
#   [Direct_M1] Ep 64 | reward=+33.10 | profit=+91.60€ | sat=29.3% | overload=0.00kWh | Qlost=0.00041 | EVs=6
#   [Direct_M1] Ep 65 | reward=+6.71 | profit=+7.85€ | sat=61.5% | overload=0.00kWh | Qlost=0.00018 | EVs=3
#   [Direct_M1] Ep 66 | reward=+19.71 | profit=+25.67€ | sat=52.3% | overload=0.00kWh | Qlost=0.00052 | EVs=6
#   [Direct_M1] Ep 67 | reward=-32.48 | profit=+58.27€ | sat=23.3% | overload=0.00kWh | Qlost=0.00072 | EVs=9
#   [Direct_M1] Ep 68 | reward=+3.37 | profit=+26.71€ | sat=32.1% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Direct_M1] Ep 69 | reward=+9.92 | profit=+18.42€ | sat=45.0% | overload=0.00kWh | Qlost=0.00042 | EVs=6
#   [Direct_M1] Ep 70 | reward=+6.83 | profit=+19.48€ | sat=34.2% | overload=0.00kWh | Qlost=0.00014 | EVs=2
#   [Direct_M1] Ep 71 | reward=-1.68 | profit=-1.53€ | sat=80.7% | overload=0.00kWh | Qlost=0.00014 | EVs=3
#   [Direct_M1] Ep 72 | reward=+14.00 | profit=+35.32€ | sat=28.0% | overload=0.00kWh | Qlost=0.00029 | EVs=3
#   [Direct_M1] Ep 73 | reward=+42.65 | profit=+80.26€ | sat=31.2% | overload=0.00kWh | Qlost=0.00043 | EVs=5
#   [Direct_M1] Ep 74 | reward=+4.53 | profit=+6.73€ | sat=55.9% | overload=0.00kWh | Qlost=0.00023 | EVs=4
#   [Direct_M1] Ep 75 | reward=+8.51 | profit=+37.15€ | sat=35.0% | overload=0.00kWh | Qlost=0.00028 | EVs=5
#   [Direct_M1] Ep 76 | reward=-18.91 | profit=+39.10€ | sat=24.9% | overload=0.00kWh | Qlost=0.00048 | EVs=6
#   [Direct_M1] Ep 77 | reward=-6.66 | profit=+7.53€ | sat=39.3% | overload=0.00kWh | Qlost=0.00028 | EVs=4
#   [Direct_M1] Ep 78 | reward=+7.14 | profit=+77.53€ | sat=21.4% | overload=0.00kWh | Qlost=0.00061 | EVs=6
#   [Direct_M1] Ep 79 | reward=+4.14 | profit=+10.96€ | sat=55.3% | overload=0.00kWh | Qlost=0.00046 | EVs=7
#   [Direct_M1] Ep 80 | reward=-0.51 | profit=+12.67€ | sat=31.9% | overload=0.00kWh | Qlost=0.00014 | EVs=2
#   [Direct_M1] Ep 81 | reward=-5.12 | profit=+17.73€ | sat=36.0% | overload=0.00kWh | Qlost=0.00025 | EVs=4
#   [Direct_M1] Ep 82 | reward=+7.50 | profit=+9.27€ | sat=61.5% | overload=0.00kWh | Qlost=0.00028 | EVs=4
#   [Direct_M1] Ep 83 | reward=+43.14 | profit=+83.51€ | sat=23.5% | overload=0.00kWh | Qlost=0.00031 | EVs=4
#   [Direct_M1] Ep 84 | reward=+1.23 | profit=+1.97€ | sat=49.0% | overload=0.00kWh | Qlost=0.00003 | EVs=1
#   [Direct_M1] Ep 85 | reward=+1.76 | profit=+9.65€ | sat=25.4% | overload=0.00kWh | Qlost=0.00007 | EVs=1
#   [Direct_M1] Ep 86 | reward=+33.35 | profit=+37.16€ | sat=58.0% | overload=0.00kWh | Qlost=0.00067 | EVs=6
#   [Direct_M1] Ep 87 | reward=+4.79 | profit=+32.05€ | sat=33.0% | overload=0.00kWh | Qlost=0.00040 | EVs=6
#   [Direct_M1] Ep 88 | reward=+1.47 | profit=+12.70€ | sat=37.5% | overload=0.00kWh | Qlost=0.00026 | EVs=4
#   [Direct_M1] Ep 89 | reward=+32.53 | profit=+83.02€ | sat=32.0% | overload=0.00kWh | Qlost=0.00057 | EVs=7
#   [Direct_M1] Ep 90 | reward=+9.93 | profit=+16.36€ | sat=43.0% | overload=0.00kWh | Qlost=0.00033 | EVs=3
#   [Direct_M1] Ep 91 | reward=+38.02 | profit=+66.11€ | sat=46.6% | overload=0.00kWh | Qlost=0.00080 | EVs=6
#   [Direct_M1] Ep 92 | reward=+14.55 | profit=+28.44€ | sat=36.1% | overload=0.00kWh | Qlost=0.00032 | EVs=4
#   [Direct_M1] Ep 93 | reward=-6.00 | profit=+35.19€ | sat=35.5% | overload=0.00kWh | Qlost=0.00033 | EVs=6
#   [Direct_M1] Ep 94 | reward=+70.34 | profit=+123.89€ | sat=27.9% | overload=0.00kWh | Qlost=0.00055 | EVs=6
#   [Direct_M1] Ep 95 | reward=+4.15 | profit=+25.29€ | sat=35.9% | overload=0.00kWh | Qlost=0.00026 | EVs=4
#   [Direct_M1] Ep 96 | reward=-6.69 | profit=+17.51€ | sat=40.2% | overload=0.00kWh | Qlost=0.00034 | EVs=5
#   [Direct_M1] Ep 97 | reward=+7.91 | profit=+31.37€ | sat=21.4% | overload=0.00kWh | Qlost=0.00021 | EVs=2
#   [Direct_M1] Ep 98 | reward=+38.21 | profit=+76.87€ | sat=24.5% | overload=0.00kWh | Qlost=0.00039 | EVs=4
#   [Direct_M1] Ep 99 | reward=-1.29 | profit=+21.87€ | sat=37.7% | overload=0.00kWh | Qlost=0.00041 | EVs=7
#   [Direct_M1] Ep 100 | reward=+1.51 | profit=+36.70€ | sat=21.4% | overload=0.00kWh | Qlost=0.00023 | EVs=3
#
# ABLATION RESULTS:
#   Proxy (Model-2)        profit=+36.26+/-35.33  sat=38.0%  ov=0.0 kWh
#   Direct (Model-1)       profit=+36.20+/-35.35  sat=41.1%  ov=0.0 kWh
#
# Saved: ablation_proxy_vs_direct.csv
